# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Understanding-the-Data" data-toc-modified-id="Understanding-the-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Understanding the Data</a></span><ul class="toc-item"><li><span><a href="#Metadata-File" data-toc-modified-id="Metadata-File-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span><code>Metadata</code> File</a></span><ul class="toc-item"><li><span><a href="#Metadata-Exploration" data-toc-modified-id="Metadata-Exploration-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span><code>Metadata</code> Exploration</a></span><ul class="toc-item"><li><span><a href="#Checking-out-split-Column" data-toc-modified-id="Checking-out-split-Column-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Checking out <code>split</code> Column</a></span></li><li><span><a href="#Checking-out-date-Column" data-toc-modified-id="Checking-out-date-Column-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>Checking out <code>date</code> Column</a></span></li></ul></li></ul></li><li><span><a href="#Taking-a-look-at-train_labels-File" data-toc-modified-id="Taking-a-look-at-train_labels-File-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Taking a look at train_labels File</a></span><ul class="toc-item"><li><span><a href="#Taking-a-look-at-severity" data-toc-modified-id="Taking-a-look-at-severity-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Taking a look at <code>severity</code></a></span></li><li><span><a href="#Taking-a-look-at-region" data-toc-modified-id="Taking-a-look-at-region-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Taking a look at <code>region</code></a></span></li><li><span><a href="#Severity-by-Region" data-toc-modified-id="Severity-by-Region-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Severity by Region</a></span></li></ul></li><li><span><a href="#Checking-for-the-Timeframe-of-Data" data-toc-modified-id="Checking-for-the-Timeframe-of-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Checking for the Timeframe of Data</a></span></li><li><span><a href="#Setting-Date-as-the-Index" data-toc-modified-id="Setting-Date-as-the-Index-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Setting Date as the Index</a></span><ul class="toc-item"><li><span><a href="#Adding-Seasons-to-MetaData" data-toc-modified-id="Adding-Seasons-to-MetaData-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Adding Seasons to <code>MetaData</code></a></span></li></ul></li><li><span><a href="#Splitting-the-Data-into-Train-and-Test-Sets" data-toc-modified-id="Splitting-the-Data-into-Train-and-Test-Sets-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Splitting the Data into Train and Test Sets</a></span><ul class="toc-item"><li><span><a href="#Adding-Labels-to-train-data" data-toc-modified-id="Adding-Labels-to-train-data-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Adding Labels to train data</a></span></li></ul></li></ul></li><li><span><a href="#Geopandas" data-toc-modified-id="Geopandas-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Geopandas</a></span><ul class="toc-item"><li><span><a href="#Moving-on-to-Metadata-in-GeoPandas" data-toc-modified-id="Moving-on-to-Metadata-in-GeoPandas-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Moving on to <code>Metadata</code> in GeoPandas</a></span></li><li><span><a href="#Mapping-Sample-Location-by-Season" data-toc-modified-id="Mapping-Sample-Location-by-Season-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Mapping Sample Location by Season</a></span></li><li><span><a href="#Mapping-Severity-by-Location-for-Train-Data" data-toc-modified-id="Mapping-Severity-by-Location-for-Train-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Mapping Severity by Location for Train Data</a></span></li></ul></li><li><span><a href="#Time-Trends" data-toc-modified-id="Time-Trends-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Time Trends</a></span><ul class="toc-item"><li><span><a href="#Visualizing-Number-of-Samples-taken-over-Time" data-toc-modified-id="Visualizing-Number-of-Samples-taken-over-Time-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Visualizing Number of Samples taken over Time</a></span><ul class="toc-item"><li><span><a href="#Plotting-Monthly-Trends" data-toc-modified-id="Plotting-Monthly-Trends-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Plotting Monthly Trends</a></span></li></ul></li><li><span><a href="#Visualizing-Severity-over-Time-by-Region" data-toc-modified-id="Visualizing-Severity-over-Time-by-Region-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Visualizing Severity over Time by Region</a></span><ul class="toc-item"><li><span><a href="#Visualizing-Regional-Severity-over-Time" data-toc-modified-id="Visualizing-Regional-Severity-over-Time-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Visualizing Regional Severity over Time</a></span></li></ul></li><li><span><a href="#Looking-at-Annual-Trends-in-data" data-toc-modified-id="Looking-at-Annual-Trends-in-data-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Looking at Annual Trends in data</a></span><ul class="toc-item"><li><span><a href="#Train-Data" data-toc-modified-id="Train-Data-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Train Data</a></span></li><li><span><a href="#Test-Data" data-toc-modified-id="Test-Data-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Test Data</a></span></li><li><span><a href="#Barplot-of-annual-samples" data-toc-modified-id="Barplot-of-annual-samples-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Barplot of annual samples</a></span></li></ul></li><li><span><a href="#Lets-look-at-the-other-import" data-toc-modified-id="Lets-look-at-the-other-import-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Lets look at the other import</a></span></li><li><span><a href="#Sat-imagery" data-toc-modified-id="Sat-imagery-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Sat imagery</a></span></li></ul></li></ul></div>

# %% [markdown]
# Running main notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import geopandas as gpd
from shapely.geometry import Point
import geopy.distance as distance

import planetary_computer as pc
from pystac_client import Client

from datetime import datetime
from datetime import timedelta

import warnings
warnings.filterwarnings('ignore')

# %%
# pip install planetary_computer

# %% [markdown]
# # Understanding the Data

# %% [markdown]
# ## `Metadata` File

# %% [markdown]
# - `uid` (str): unique ID for each row
# - `latitude` (float): latitude of the location where the sample was collected
# - `longitude` (float): longitude of the location where the sample was collected
# - `date` (pd.datetime): date when the sample was collected, in the format YYYY-MM-DD
# - `split` (str): indicates whether the row is part of the train set or the test set

# %%
# Reading in the data and bringing in date as datetime dtype
metadata = pd.read_csv('Data/metadata.csv', parse_dates=['date'])

# %%
metadata.head()
# Out:
#     uid   latitude   longitude       date  split
# 0  aabm  39.080319  -86.430867 2018-05-14  train
# 1  aabn  36.559700 -121.510000 2016-08-31   test
# 2  aacd  35.875083  -78.878434 2020-11-19  train
# 3  aaee  35.487000  -79.062133 2016-08-24  train
# 4  aaff  38.049471  -99.827001 2019-07-23  train

# %% [markdown]
# ### `Metadata` Exploration

# %% [markdown]
# 23570 rows of information with no nulls. Dtypes are as to be expected, no additional changes needed.

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23570 entries, 0 to 23569
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   uid        23570 non-null  object
#  1   latitude   23570 non-null  float64
#  2   longitude  23570 non-null  float64
#  3   date       23570 non-null  datetime64[ns]
#  4   split      23570 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 920.8+ KB

# %% [markdown]
# #### Checking out `split` Column

# %% [markdown]
# 72.4% of the data is labeled as training data and 27.6% of data is test data.

# %%
metadata['split'].value_counts(normalize=True)
# Out:
# train    0.723801
# test     0.276199
# Name: split, dtype: float64

# %% [markdown]
# #### Checking out `date` Column

# %% [markdown]
# Dates are not a unique identifier. Multiple datapoints can come from the same day.

# %%
metadata['date'].value_counts()
# Out:
# 2016-08-10    146
# 2015-07-07    112
# 2015-06-22    103
# 2015-08-24    103
# 2016-05-24     99
#              ...
# 2017-02-10      1
# 2018-04-30      1
# 2019-10-25      1
# 2014-09-17      1
# 2013-12-08      1
# Name: date, Length: 1637, dtype: int64

# %% [markdown]
# ## Taking a look at train_labels File

# %% [markdown]
# - `uid` (str): unique ID for each row. `uid` maps each row of the labels to a row in metadata.csv.
# - `region` (str): U.S. region in which the sample was taken. Scores are calculated separately for each of these regions and then averaged.
# - `severity` (int): severity level based on the cyanobacteria density.
# - `density` (float): raw measurement of total cyanobacteria density in cells per mL.

# %%
train_labels = pd.read_csv('Data/train_labels.csv')

# %%
train_labels.head()
# Out:
#     uid   region  severity    density
# 0  aabm  midwest         1      585.0
# 1  aacd    south         1      290.0
# 2  aaee    south         1     1614.0
# 3  aaff  midwest         3   111825.0
# 4  aafl  midwest         4  2017313.0

# %% [markdown]
# ### Taking a look at `severity`

# %% [markdown]
# Values range on a scale of 1-5. Majority (44%) of severity levels are 1.

# %%
train_labels['severity'].value_counts()
# Out:
# 1    7497
# 4    3547
# 2    3239
# 3    2719
# 5      58
# Name: severity, dtype: int64

# %%
train_labels['severity'].value_counts(normalize=True)
# Out:
# 1    0.439449
# 4    0.207913
# 2    0.189859
# 3    0.159379
# 5    0.003400
# Name: severity, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(6,5))

x=train_labels['severity'].value_counts(normalize=True).index
y=train_labels['severity'].value_counts(normalize=True)

sns.barplot(x=x, y=y, ax=ax)
ax.set_ylabel('Percentage of Samples')
ax.set_xlabel('Severity')
ax.set_title('Train Labels Severity Percents');

# %% [markdown]
# ### Taking a look at `region`

# %% [markdown]
# The South is the region with the most samples, roughly 58% of all samples were taken from the South.

# %%
train_labels['region'].value_counts()
# Out:
# south        9948
# west         3769
# midwest      2200
# northeast    1143
# Name: region, dtype: int64

# %%
train_labels['region'].value_counts(normalize=True)
# Out:
# south        0.583118
# west         0.220926
# midwest      0.128957
# northeast    0.066999
# Name: region, dtype: float64

# %% [markdown]
# ### Severity by Region

# %% [markdown]
# Checking the breakdown of average severity by region, we can see that the west has a much higher relative severity than the other regions.

# %%
train_regions = train_labels.groupby('region').mean()

# %%
fig, ax = plt.subplots(figsize=(8,5))
train_regions['severity'].plot(kind='bar', rot=45)

ax.set_xlabel('Region')
ax.set_ylabel('Severity Level')
ax.set_title('Average Severity by Region');

# %% [markdown]
# ## Checking for the Timeframe of Data

# %% [markdown]
# First Sample was taken January 4th, 2013 and the last sample was taken December 29th, 2021.

# %%
metadata.agg({'date': ['min', 'max']})
# Out:
#           date
# min 2013-01-04
# max 2021-12-29

# %% [markdown]
# ## Setting Date as the Index

# %% [markdown]
# Setting index for MetaData

# %%
metadata = metadata.set_index('date')

# %%
metadata.sort_index(inplace=True)

# %%
metadata.head()
# Out:
#              uid   latitude  longitude  split
# date
# 2013-01-04  evep  44.847993 -93.476318  train
# 2013-01-04  paev  44.822478 -93.367962  train
# 2013-01-04  gdxr  44.877646 -93.557842  train
# 2013-01-04  guny  44.878889 -93.490833  train
# 2013-01-04  fwbt  44.850500 -93.515700  train

# %% [markdown]
# ### Adding Seasons to `MetaData`

# %% [markdown]
# The majority (roughly 45%) of sampling took place in summer months.

# %%
seasons = {12: 'winter', 1: 'winter', 2: 'winter', 3:'spring', 4:'spring', 5:'spring',
           6:'summer', 7:'summer', 8:'summer', 9:'autumn', 10:'autumn', 11:'autumn'}

# %%
metadata['season'] = metadata.index.month.map(seasons)

# %%
metadata.head()
# Out:
#              uid   latitude  longitude  split  season
# date
# 2013-01-04  evep  44.847993 -93.476318  train  winter
# 2013-01-04  paev  44.822478 -93.367962  train  winter
# 2013-01-04  gdxr  44.877646 -93.557842  train  winter
# 2013-01-04  guny  44.878889 -93.490833  train  winter
# 2013-01-04  fwbt  44.850500 -93.515700  train  winter

# %%
metadata['season'].value_counts(normalize=True)
# Out:
# summer    0.458761
# spring    0.214043
# autumn    0.201867
# winter    0.125329
# Name: season, dtype: float64

# %% [markdown]
# ## Splitting the Data into Train and Test Sets

# %%
X_train = metadata[metadata['split'] == 'train']

# %%
X_test = metadata[metadata['split'] == 'test']

# %% [markdown]
# ### Adding Labels to train data

# %%
X_train = X_train.merge(train_labels, on='uid').set_index(X_train.index)

# %%
X_train.head()
# Out:
#              uid   latitude  longitude  split  season   region  severity  \
# date
# 2013-01-04  evep  44.847993 -93.476318  train  winter  midwest         1
# 2013-01-04  paev  44.822478 -93.367962  train  winter  midwest         1
# 2013-01-04  gdxr  44.877646 -93.557842  train  winter  midwest         1
# 2013-01-04  guny  44.878889 -93.490833  train  winter  midwest         1
# 2013-01-04  fwbt  44.850500 -93.515700  train  winter  midwest         1
#
#             density
# date
# 2013-01-04    115.0
# 2013-01-04   1884.0
# 2013-01-04   1416.0
# 2013-01-04    558.0
# 2013-01-04    476.0

# %% [markdown]
# # Geopandas

# %% [markdown]
# Testing geopandas to see how it works

# %% [markdown]
# ## Moving on to `Metadata` in GeoPandas

# %%
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %%
# Creating Geopandas dataframes for train and test sets
X_train_geo_df = gpd.GeoDataFrame(X_train, geometry=gpd.points_from_xy(X_train['longitude'], X_train['latitude']))
X_test_geo_df = gpd.GeoDataFrame(X_test, geometry=gpd.points_from_xy(X_test['longitude'], X_test['latitude']))

# %%
fig, ax = plt.subplots(figsize=(20,20))
USA_map = world[world['name'] == 'United States of America'].plot(ax=ax, color='white', edgecolor='black')
X_train_geo_df.plot(ax=ax, c='r', label='Train')
X_test_geo_df.plot(ax=ax, c='b', label='Test')

ax.set_xlim([-128, -65])
ax.set_ylim([23, 53])
ax.legend(markerscale=2, fontsize =20)
ax.set_axis_off()
ax.set_title('Chlorophyll Sample Locations', fontsize=25);

# %% [markdown]
# ## Mapping Sample Location by Season

# %%
meta_geo_df = gpd.GeoDataFrame(metadata, geometry=gpd.points_from_xy(metadata['longitude'], metadata['latitude']))

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(20,10))


for n, season in enumerate(meta_geo_df['season'].unique()):
    j = n%2
    i = n//2
    ax = axes[i,j]
    
    # Setting a basemap of the USA
    USA_map = world[world['name'] == 'United States of America'].plot(ax=ax, color='white', edgecolor='black')
    
    data = meta_geo_df[meta_geo_df['season'] == season]
    data.plot(ax=ax, markersize=8, alpha=.5)
    
    
    ax.set_xlim([-128, -65])
    ax.set_ylim([23, 53])
    ax.set_axis_off()
    ax.set_title(f'{season.title()} Samples', fontsize=25);

# %% [markdown]
# ## Mapping Severity by Location for Train Data

# %%
X_train_geo_df.head()
# Out:
#              uid   latitude  longitude  split  season   region  severity  \
# date
# 2013-01-04  evep  44.847993 -93.476318  train  winter  midwest         1
# 2013-01-04  paev  44.822478 -93.367962  train  winter  midwest         1
# 2013-01-04  gdxr  44.877646 -93.557842  train  winter  midwest         1
# 2013-01-04  guny  44.878889 -93.490833  train  winter  midwest         1
# 2013-01-04  fwbt  44.850500 -93.515700  train  winter  midwest         1
#
#             density                    geometry
# date
# 2013-01-04    115.0  POINT (-93.47632 44.84799)
# 2013-01-04   1884.0  POINT (-93.36796 44.82248)
# 2013-01-04   1416.0  POINT (-93.55784 44.87765)
# 2013-01-04    558.0  POINT (-93.49083 44.87889)
# 2013-01-04    476.0  POINT (-93.51570 44.85050)

# %%
fig, ax = plt.subplots(figsize=(20,15))
# Setting a basemap of the USA
USA_map = world[world['name'] == 'United States of America'].plot(ax=ax, color='white', edgecolor='black')

# Labeling the recorded severity levels
X_train_geo_df.plot(ax=ax,
                    column='severity',
                    categorical=True,
                    cmap='crest',
                    legend=True,
                    legend_kwds={'markerscale':1.25,
                                'fontsize':'large',
                                'title':'Recorded Severity Levels',
                                'title_fontsize':'x-large',
                                'ncols':2})


ax.set_xlim([-128, -65])
ax.set_ylim([23, 53])
ax.set_title('Train Severity by Location', fontsize=25);

# %% [markdown]
# # Time Trends

# %% [markdown]
# ## Visualizing Number of Samples taken over Time

# %% [markdown]
# Train data and rolling mean

# %%
X_train_months = X_train.groupby(pd.Grouper(freq = 'MS')).count()

# %%
train_roll_mean = X_train_months['split'].rolling(window=12).mean()

# %% [markdown]
# Test data and rolling mean

# %%
X_test_months = X_test.groupby(pd.Grouper(freq = 'MS')).count()

# %%
test_roll_mean = X_test_months['split'].rolling(window=12).mean()

# %% [markdown]
# ### Plotting Monthly Trends

# %% [markdown]
# Plotting sample counts per month with a 12-month rolling mean. Similar sampling patterns in training and test data. High seasonality.

# %%
fig, ax= plt.subplots(figsize=(15,10))
# train data
X_train_months.plot(y='split', ax=ax, label='# Train Samples', style='b')
train_roll_mean.plot(ax=ax, label='Train 12-Month Mean', style='--b')

# test data
X_test_months.plot(y='split', ax=ax, label='# Test Samples', style='g')
test_roll_mean.plot(ax=ax, label='Test 12-Month Mean', style='--g')

ax.set_title('# of Samples Taken per Month')
ax.legend();

# %% [markdown]
# ## Visualizing Severity over Time by Region

# %% [markdown]
# Creating regional Dataframes

# %%
west_df = X_train[X_train['region']=='west']
south_df = X_train[X_train['region']=='south']
northeast_df = X_train[X_train['region']=='northeast']
midwest_df = X_train[X_train['region']=='midwest']

# %% [markdown]
# Western Severity

# %%
west_severity_monthly = west_df.groupby(pd.Grouper(freq = 'MS')).mean()
west_severity_rolling = west_severity_monthly['severity'].rolling(window=12).mean()

# %% [markdown]
# Southern Severity

# %%
south_severity_monthly = south_df.groupby(pd.Grouper(freq = 'MS')).mean()
# Filling in missing data with linear data for plotting
south_severity_monthly = south_severity_monthly.interpolate(method='slinear')
south_severity_rolling = south_severity_monthly['severity'].rolling(window=12).mean()

# %% [markdown]
# Northeast Severity

# %%
n_e_severity_monthly = northeast_df.groupby(pd.Grouper(freq = 'MS')).mean()
# Filling in missing data with linear data for plotting
n_e_severity_monthly = n_e_severity_monthly.interpolate(method='linear')
n_e_severity_rolling = n_e_severity_monthly['severity'].rolling(window=12).mean()

# %% [markdown]
# Midwest Monthly Severity

# %%
midwest_severity_monthly = midwest_df.groupby(pd.Grouper(freq = 'MS')).mean()
# Filling in missing data with linear data for plotting
midwest_severity_monthly = midwest_severity_monthly.interpolate(method='linear')
midwest_severity_rolling = midwest_severity_monthly['severity'].rolling(window=12).mean()

# %% [markdown]
# ### Visualizing Regional Severity over Time

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, sharey=True, figsize=(20,20))
# west data
ax1=axes[0,0]
west_severity_monthly.plot(y='severity', ax=ax1, label='West', style='b')
west_severity_rolling.plot(ax=ax1, label='West 12-Month Mean', style='--b')

# South Data
ax2 = axes[0,1]
south_severity_monthly.plot(y='severity', ax=ax2, label='South', style='r')
south_severity_rolling.plot(ax=ax2, label='South 12-Month Mean', style='--r')

# Northeast Data
ax3 = axes[1,0]
n_e_severity_monthly.plot(y='severity', ax=ax3, label='Northeast', style='g')
n_e_severity_rolling.plot(ax=ax3, label='Northeast 12-Month Mean', style='--g')

# Midwest Data
ax4 = axes[1,1]
midwest_severity_monthly.plot(y='severity', ax=ax4, label='Midwest', style='y')
midwest_severity_rolling.plot(ax=ax4, label='Midwest 12-Month Mean', style='--y')



axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.set_ylabel('Severity')
    ax.set_xlabel('Date')
    ax.set_title('Average Monthly Severity')
    ax.legend();

# %% [markdown]
# ## Looking at Annual Trends in data

# %% [markdown]
# ### Train Data

# %%
train_year_groups = X_train_months['uid'].groupby(pd.Grouper(freq='A'))

# %%
annual_samples = {}

for yr, group in train_year_groups:
    annual_samples[yr.year] = pd.DataFrame(group.values.ravel(), columns=[yr.year])
    
    
annual_samples_df = pd.concat(annual_samples.values(), axis=1, )

# %%
# setting the index to match month names
annual_df_indexed = annual_samples_df.set_index(annual_samples_df.index+1)

# %%
annual_df_indexed.plot(kind='bar', figsize = (13,20), subplots=True, legend=True, sharey=True);

# %% [markdown]
# ### Test Data

# %%
test_year_groups = X_test_months['uid'].groupby(pd.Grouper(freq='A'))

# %%
annual_samples_test = {}

for yr, group in test_year_groups:
    annual_samples_test[yr.year] = pd.DataFrame(group.values.ravel(), columns=[yr.year])
    
    
annual_samples_test_df = pd.concat(annual_samples_test.values(), axis=1, )

# %%
# setting the index to match month names
annual_df_test_indexed = annual_samples_test_df.set_index(annual_samples_test_df.index+1)

# %%
annual_df_test_indexed.plot(kind='bar', figsize = (13,20), subplots=True, legend=True, sharey=True);

# %%
# total samples in each year
test_total_annual = annual_samples_test_df.sum()
test_total_annual
# Out:
# 2013     521
# 2014     602
# 2015     527
# 2016     625
# 2017    1031
# 2018     777
# 2019    1199
# 2020     546
# 2021     682
# dtype: int64

# %% [markdown]
# ### Barplot of annual samples

# %%
# total samples in each year
train_total_annual = annual_samples_df.sum()
train_total_annual
# Out:
# 2013    1362
# 2014    1504
# 2015    2299
# 2016    2428
# 2017    2435
# 2018    1940
# 2019    1788
# 2020    1706
# 2021    1598
# dtype: int64

# %%
# total samples in each year
test_total_annual = annual_samples_test_df.sum()
test_total_annual
# Out:
# 2013     521
# 2014     602
# 2015     527
# 2016     625
# 2017    1031
# 2018     777
# 2019    1199
# 2020     546
# 2021     682
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,10))
train_total_annual.plot(kind='bar', label='train', ax=ax)
test_total_annual.plot(kind='bar', label='test', ax=ax, color='lightblue')
ax.legend();

# %% [markdown]
# ## Sat imagery

# %%
catalog = Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1", modifier=pc.sign_inplace
)

# %% [markdown]
# Proof of concept to get distances between two points

# %%
newport_ri = (41.49008, -71.312796)
cleveland_oh = (41.499498, -81.695391)
print(distance.distance(newport_ri, cleveland_oh).miles)
# Out:
# 538.3904453677205

# %% [markdown]
# Me getting a half mile distance from the test point

# %%
# Bounding box must be within (-180, -90, 180, 90)

# So its east, north, west, south?

# %%
def create_bbox(coords_df, dist=.5):

    '''
    Input a dataframe that includes lat/long and outputs a list of bbox's for each row 
    '''
    bbox_list = []
#     list_of_coords = list_of_coords.index
    
    for n in range(len(coords_df)):
        coord = coords_df.iloc[n]
        bbox = []
        bbox.append(distance.distance(miles=dist).destination((coord.latitude, coord.longitude), bearing=270)[1])
        bbox.append(distance.distance(miles=dist).destination((coord.latitude, coord.longitude), bearing=180)[0])
        bbox.append(distance.distance(miles=dist).destination((coord.latitude, coord.longitude), bearing=90)[1])
        bbox.append(distance.distance(miles=dist).destination((coord.latitude, coord.longitude), bearing=0)[0])
        bbox_list.append(bbox)
#         bbox_list.append(n)
    coords_df[f"bbox_{dist}_miles"] = bbox_list
    return coords_df

# %%
def get_date_range(date_df, range_in_days=15):
    
    '''
    input a dataframe with a date as the index and specify range of dates.
    Will create new column in df that has daterange for sat image pulling.
    '''
    
    range_list = []
    
    for n in date_df.index:
        date = pd.to_datetime(n).strftime(format="%Y-%m-%dT")
        day_range = (n-timedelta(range_in_days)).strftime(format="%Y-%m-%dT")
        final_range = f"{day_range}/{date}"
        
        
        range_list.append(final_range)
    date_df[f"{range_in_days}_date_range"] = range_list
    return date_df

# %%
def get_important_info(df, dist=.5, range_in_days=15):
    
    get_date_range(df)
    create_bbox(df)
    return(df)

# %%
get_important_info(X_train)
# Out:
#              uid   latitude  longitude  split                    geometry  \
# date
# 2013-01-04  fwbt  44.850500 -93.515700  train  POINT (-93.51570 44.85050)
# 2013-01-04  guny  44.878889 -93.490833  train  POINT (-93.49083 44.87889)
# 2013-01-04  gdxr  44.877646 -93.557842  train  POINT (-93.55784 44.87765)
# 2013-01-04  paev  44.822478 -93.367962  train  POINT (-93.36796 44.82248)
# 2013-01-04  evep  44.847993 -93.476318  train  POINT (-93.47632 44.84799)
# ...          ...        ...        ...    ...                         ...
# 2021-12-14  tobi  36.030000 -78.705932  train  POINT (-78.70593 36.03000)
# 2021-12-14  mdcu  35.980000 -78.843884  train  POINT (-78.84388 35.98000)
# 2021-12-14  hkvs  36.030000 -78.706429  train  POINT (-78.70643 36.03000)
# 2021-12-14  uscb  35.980000 -78.843636  train  POINT (-78.84364 35.98000)
# 2021-12-14  zoaj  36.060000 -78.760000  train  POINT (-78.76000 36.06000)
#
#                       15_date_range  \
# date
# ...

# %%
X_train.head()
# Out:
#              uid   latitude  longitude  split                    geometry  \
# date
# 2013-01-04  fwbt  44.850500 -93.515700  train  POINT (-93.51570 44.85050)
# 2013-01-04  guny  44.878889 -93.490833  train  POINT (-93.49083 44.87889)
# 2013-01-04  gdxr  44.877646 -93.557842  train  POINT (-93.55784 44.87765)
# 2013-01-04  paev  44.822478 -93.367962  train  POINT (-93.36796 44.82248)
# 2013-01-04  evep  44.847993 -93.476318  train  POINT (-93.47632 44.84799)
#
#                       15_date_range  \
# date
# 2013-01-04  2012-12-20T/2013-01-04T
# 2013-01-04  2012-12-20T/2013-01-04T
# 2013-01-04  2012-12-20T/2013-01-04T
# 2013-01-04  2012-12-20T/2013-01-04T
# 2013-01-04  2012-12-20T/2013-01-04T
#
#                                                bbox_0.5_miles
# date
# 2013-01-04  [-93.52587907205879, 44.84325910378526, -93.50...
# 2013-01-04  [-93.50101707612784, 44.87164813993163, -93.48...
# 2013-01-04  [-93.56802585687116, 44.870405138348964, -93.5...
# ...

# %%
bbox = X_train['bbox_0.5_miles'][0]

# %%
bbox
# Out:
# [-93.52587907205879, 44.84325910378526, -93.5055209279412, 44.85774088699526]

# %%
date = X_train['15_date_range'][0]

# %%
date
# Out:
# '2012-12-20T/2013-01-04T'

# %%
# search the planetary computer sentinel-l2a and landsat level-2 collections
search = catalog.search(
    collections=["sentinel-2-l2a", "landsat-c2-l2"], bbox=bbox, datetime=date
)

# %%
search_dic = search.get_all_items_as_dict()

# %%
len(search_dic)
# Out:
# 2

# %%
search_dic.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
search_dic['features'][0]
# Out:
# {'id': 'LE07_L2SP_027029_20121226_02_T2',
#  'bbox': [-95.12924581, 43.60162506, -91.96768777, 45.59541494],
#  'type': 'Feature',
#  'links': [{'rel': 'collection',
#    'type': 'application/json',
#    'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2'},
#   {'rel': 'parent',
#    'type': 'application/json',
#    'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2'},
#   {'rel': 'root',
#    'type': 'application/json',
#    'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/'},
#   {'rel': 'self',
#    'type': 'application/geo+json',
#    'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LE07_L2SP_027029_20121226_02_T2'},
#   {'rel': 'cite-as',
#    'href': 'https://doi.org/10.5066/P9C7I13B',
#    'title': 'Landsat 7 ETM+ Collection 2 Level-2'},
#   {'rel': 'via',
# ...

# %%
search_dic['type']
# Out:
# 'FeatureCollection'

# %%
search_dic['features'][0].keys()
# Out:
# dict_keys(['id', 'bbox', 'type', 'links', 'assets', 'geometry', 'collection', 'properties', 'stac_extensions', 'stac_version'])
