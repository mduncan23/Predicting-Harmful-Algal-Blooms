# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importing-the-Data" data-toc-modified-id="Importing-the-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importing the Data</a></span><ul class="toc-item"><li><span><a href="#Metadata-File" data-toc-modified-id="Metadata-File-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span><code>Metadata</code> File</a></span></li><li><span><a href="#train_labels-File" data-toc-modified-id="train_labels-File-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span><code>train_labels</code> File</a></span></li><li><span><a href="#Prepping-the-data-for-the-Satellite-imagery-analysis." data-toc-modified-id="Prepping-the-data-for-the-Satellite-imagery-analysis.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Prepping the data for the Satellite imagery analysis.</a></span></li><li><span><a href="#Setting-up-the-DataFrame" data-toc-modified-id="Setting-up-the-DataFrame-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Setting up the DataFrame</a></span></li></ul></li><li><span><a href="#Temperature-Data" data-toc-modified-id="Temperature-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Temperature Data</a></span></li><li><span><a href="#This-is-me-doing-crazy-stuff" data-toc-modified-id="This-is-me-doing-crazy-stuff-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>This is me doing crazy stuff</a></span><ul class="toc-item"><li><span><a href="#Trying-from-aws" data-toc-modified-id="Trying-from-aws-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Trying from aws</a></span></li></ul></li></ul></div>

# %% [markdown]
# Running main notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import geopandas as gpd
from shapely.geometry import Point
import geopy.distance as distance

import planetary_computer as pc
from pystac_client import Client

from datetime import datetime, date
from datetime import timedelta

# from keras.utils import load_img, img_to_array
import requests
from PIL import Image
from io import BytesIO

from tqdm import tqdm
tqdm.pandas()

import rioxarray
import cv2
import odc.stac
import tempfile
import rasterio
import os

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

import functions
import functions2

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the Data

# %% [markdown]
# ## `Metadata` File

# %%
# Reading in the data and bringing in date as datetime dtype
metadata = pd.read_csv('Data/metadata.csv', parse_dates=['date'])

# %% [markdown]
# ## `train_labels` File

# %%
train_labels = pd.read_csv('Data/train_labels.csv')

# %% [markdown]
# ## Prepping the data for the Satellite imagery analysis.

# %%
sat_df = metadata

# %%
sat_df
# Out:
#         uid   latitude   longitude       date  split
# 0      aabm  39.080319  -86.430867 2018-05-14  train
# 1      aabn  36.559700 -121.510000 2016-08-31   test
# 2      aacd  35.875083  -78.878434 2020-11-19  train
# 3      aaee  35.487000  -79.062133 2016-08-24  train
# 4      aaff  38.049471  -99.827001 2019-07-23  train
# ...     ...        ...         ...        ...    ...
# 23565  zzvv  36.708500 -121.749000 2014-12-02   test
# 23566  zzwo  39.792190  -99.971050 2017-06-19  train
# 23567  zzwq  35.794000  -79.012551 2015-03-24  train
# 23568  zzyb  35.742000  -79.238600 2016-11-21  train
# 23569  zzzi  39.767323  -96.028617 2015-08-31   test
#
# [23570 rows x 5 columns]

# %%
sat_df['split'].value_counts()
# Out:
# train    17060
# test      6510
# Name: split, dtype: int64

# %%
sat_train = sat_df[sat_df['split'] == 'train'].copy()
sat_test = sat_df[sat_df['split'] == 'test'].copy()

# %% [markdown]
# Bringing back in the labels for sat_train.

# %%
sat_train = sat_train.merge(train_labels, on='uid')

# %% [markdown]
# ## Setting up the DataFrame

# %% [markdown]
# Here I use a custom function to add a date range that the satellites can interpret and also include bounding boxes to later manipulate the images.

# %%
functions.get_important_info(sat_train, dist=31, big_crop_dist=3000, small_crop_dist=500, tiny_crop_dist=100);

# %%
sat_train.head(3)
# Out:
#     uid   latitude  longitude       date  split   region  severity  density  \
# 0  aabm  39.080319 -86.430867 2018-05-14  train  midwest         1    585.0
# 1  aacd  35.875083 -78.878434 2020-11-19  train    south         1    290.0
# 2  aaee  35.487000 -79.062133 2016-08-24  train    south         1   1614.0
#
#               date_range                                               bbox  \
# 0  2018-04-29/2018-05-14  [-87.00742888244132, 38.63091417147125, -85.85...
# 1  2020-11-04/2020-11-19  [-79.43088170919651, 35.425434522510464, -78.3...
# 2  2016-08-09/2016-08-24  [-79.61191193921022, 35.03732231399556, -78.51...
#
#                                        big_crop_bbox  \
# 0  [-86.46553737052635, 39.05329612116674, -86.39...
# 1  [-78.91165478658658, 35.84804560208817, -78.84...
# 2  [-79.09519299105324, 35.459960615407574, -79.0...
#
#                                      small_crop_bbox  \
# 0  [-86.43664511758249, 39.07581525298953, -86.42...
# 1  [-78.88397103218583, 35.8705769758293, -78.872...
# 2  [-79.06764296370947, 35.48249344433146, -79.05...
#
#                                       tiny_crop_bbox
# 0  [-86.43202235685135, 39.079418305988106, -86.4...
# 1  [-78.87954163128398, 35.87418198776951, -78.87...
# 2  [-79.06323495914324, 35.48609868913609, -79.06...

# %%
functions.get_important_info(sat_test, dist=31, big_crop_dist=3000, small_crop_dist=500, tiny_crop_dist=100);

# %%
sat_test.head(3)
# Out:
#      uid   latitude  longitude       date split             date_range  \
# 1   aabn  36.559700 -121.51000 2016-08-31  test  2016-08-16/2016-08-31
# 12  aair  33.042600 -117.07600 2014-11-01  test  2014-10-17/2014-11-01
# 14  aajw  40.703968  -80.29305 2015-08-26  test  2015-08-11/2015-08-26
#
#                                                  bbox  \
# 1   [-122.06728147535146, 36.11010270440991, -120....
# 12  [-117.61009863726893, 32.59274323647839, -116....
# 14  [-80.88337803767597, 40.25468908822623, -79.70...
#
#                                         big_crop_bbox  \
# 1   [-121.5435112111439, 36.532665461053185, -121....
# 12  [-117.10811706657985, 33.01554981570179, -117....
# 14  [-80.32854854873526, 40.67695263815303, -80.25...
#
#                                       small_crop_bbox  \
# 1   [-121.515585202077, 36.55519425204005, -121.50...
# 12  [-117.08135284459203, 33.038091644106125, -117...
# 14  [-80.29896642510222, 40.69946544849961, -80.28...
#
#                                        tiny_crop_bbox
# 1   [-121.51111704041661, 36.558798850681036, -121...
# 12  [-117.07707056891928, 33.04169832908225, -117....
# 14  [-80.29423328502216, 40.70306748998178, -80.29...

# %% [markdown]
# # Temperature Data

# %%
sample_row = sat_train[sat_train['uid'] == 'garm']

# %%
sample_row
# Out:
#        uid  latitude  longitude       date  split region  severity  \
# 3950  garm  41.98006 -110.65734 2021-09-27  train   west         5
#
#           density             date_range  \
# 3950  12267752.74  2021-09-12/2021-09-27
#
#                                                    bbox  \
# 3950  [-111.25930520389633, 41.5308809188309, -110.0...
#
#                                           big_crop_bbox  \
# 3950  [-110.69353838433213, 41.953050646872555, -110...
#
#                                         small_crop_bbox  \
# 3950  [-110.6633730644045, 41.97555845000092, -110.6...
#
#                                          tiny_crop_bbox
# 3950  [-110.65854661288282, 41.97915969028358, -110....

# %%
# cleaning sample row
sample_row = sample_row[['uid', 'date', 'tiny_crop_bbox']]
sample_row = sample_row.iloc[0]

# %%
sample_row
# Out:
# uid                                                            garm
# date                                            2021-09-27 00:00:00
# tiny_crop_bbox    [-110.65854661288282, 41.97915969028358, -110....
# Name: 3950, dtype: object

# %%
# creating a sample date one day prior to real sample datetime
sample_date = sample_row['date'] - timedelta(1)

# %%
# converting to correct format
sample_date = f'{sample_date:%Y%m%d}'

# %%
sample_bbox = sample_row['tiny_crop_bbox']

# %% [markdown]
# Using AWS to pull in data

# %% [markdown]
# Pulling in all climate data for specific sample date

# %%
sector = "conus"
cycle = 12  # noon
forecast_hour = 1  # offset from cycle time
product = "wrfprsf"  # 3D Pressure Levels
sample_date = sample_date  # August 8 2019

file_path = f"hrrr.t{cycle:02}z.{product}{forecast_hour:02}.grib2"
url = f"https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.{sample_date}/{sector}/{file_path}"
print(f"Full URL: {url}")

r = requests.get(f"{url}.idx")
idx = r.text.splitlines()
# Out:
# Full URL: https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20210926/conus/hrrr.t12z.wrfprsf01.grib2

# %%
# checking for any surface level data
any_surface_data = [l for l in idx if ":surface" in l]
any_surface_data
# Out:
# ['581:288442959:d=2021092612:VIS:surface:1 hour fcst:',
#  '585:290185928:d=2021092612:GUST:surface:1 hour fcst:',
#  '607:302999940:d=2021092612:PRES:surface:1 hour fcst:',
#  '608:304501906:d=2021092612:HGT:surface:1 hour fcst:',
#  '609:306660374:d=2021092612:TMP:surface:1 hour fcst:',
#  '610:307975987:d=2021092612:ASNOW:surface:0-1 hour acc fcst:',
#  '612:309428156:d=2021092612:CNWAT:surface:1 hour fcst:',
#  '613:309485380:d=2021092612:WEASD:surface:1 hour fcst:',
#  '614:309486023:d=2021092612:SNOWC:surface:1 hour fcst:',
#  '615:309486523:d=2021092612:SNOD:surface:1 hour fcst:',
#  '627:326001314:d=2021092612:CPOFP:surface:1 hour fcst:',
#  '628:326062409:d=2021092612:PRATE:surface:1 hour fcst:',
#  '629:326097718:d=2021092612:APCP:surface:0-1 hour acc fcst:',
#  '630:326344950:d=2021092612:WEASD:surface:0-1 hour acc fcst:',
#  '631:326345443:d=2021092612:FROZR:surface:0-1 hour acc fcst:',
#  '632:326346270:d=2021092612:FRZR:surface:0-1 hour acc fcst:',
#  '633:326346583:d=2021092612:SSRUN:surface:0-1 hour acc fcst:',
#  '634:326353211:d=2021092612:BGRUN:surface:0-1 hour acc fcst:',
#  '635:326353556:d=2021092612:CSNOW:surface:1 hour fcst:',
#  '636:326353811:d=2021092612:CICEP:surface:1 hour fcst:',
#  '637:326353999:d=2021092612:CFRZR:surface:1 hour fcst:',
#  '638:326354232:d=2021092612:CRAIN:surface:1 hour fcst:',
#  '639:326401701:d=2021092612:SFCR:surface:1 hour fcst:',
#  '640:328287606:d=2021092612:FRICV:surface:1 hour fcst:',
#  '641:329459555:d=2021092612:SHTFL:surface:1 hour fcst:',
#  '642:330720979:d=2021092612:LHTFL:surface:1 hour fcst:',
#  '643:331826286:d=2021092612:GFLUX:surface:1 hour fcst:',
#  '644:332855076:d=2021092612:VGTYP:surface:1 hour fcst:',
#  '646:334693813:d=2021092612:CAPE:surface:1 hour fcst:',
#  '647:335082923:d=2021092612:CIN:surface:1 hour fcst:',
#  '661:346534769:d=2021092612:DSWRF:surface:1 hour fcst:',
#  '662:347741652:d=2021092612:DLWRF:surface:1 hour fcst:',
#  '663:349625996:d=2021092612:USWRF:surface:1 hour fcst:',
#  '664:350583476:d=2021092612:ULWRF:surface:1 hour fcst:',
#  '665:352253885:d=2021092612:CFNSF:surface:1 hour fcst:',
#  '666:352258420:d=2021092612:VBDSF:surface:1 hour fcst:',
#  '667:353798053:d=2021092612:VDDSF:surface:1 hour fcst:',
#  '688:380553945:d=2021092612:HPBL:surface:1 hour fcst:',
#  '698:394808173:d=2021092612:EFHL:surface:1 hour fcst:',
#  '703:400687731:d=2021092612:LAND:surface:1 hour fcst:',
#  '704:400738207:d=2021092612:ICEC:surface:1 hour fcst:']

# %%
# 41 potential surface data points
len(any_surface_data)
# Out:
# 41

# %%
# getting just the surface temperature data
sfc_temp_idx = [l for l in any_surface_data if ":TMP:surface" in l][0].split(":")
sfc_temp_idx
# Out:
# ['609', '306660374', 'd=2021092612', 'TMP', 'surface', '1 hour fcst', '']

# %%
# getting the line number and byte start from data
line_num = int(sfc_temp_idx[0])
range_start = sfc_temp_idx[1]
line_num, range_start
# Out:
# (609, '306660374')

# %%
# getting the next line from the index so that we can get the stop point for bytes
next_line = idx[line_num].split(':') if line_num < len(idx) else None
range_end = next_line[1] if next_line else None

# %%
# this matches with line 610 in the idx
range_end
# Out:
# '307975987'

# %%
print(rioxarray.__version__)
# Out:
# 0.13.3

# %%
rasterio.__version__
# Out:
# '1.3.4'

# %%
import tempfile
file = tempfile.NamedTemporaryFile(prefix="delete_later_", delete=False)

headers = {"Range": f"bytes={range_start}-{range_end}"}
resp = requests.get(url, headers=headers, stream=True)

with file as f:
    f.write(resp.content)

# %% [markdown]
# # This is me doing crazy stuff

# %%
rds = rioxarray.open_rasterio(file.name, parse_coordinates=True)

# %%
rds.plot()

# %%
rds.to_numpy().shape
# Out:
# (1, 1059, 1799)

# %%
rds
# Out:
# <xarray.DataArray (band: 1, y: 1059, x: 1799)>
# array([[[288.691284, 288.691284, ..., 286.066284, 286.128784],
#         [288.691284, 288.691284, ..., 286.066284, 286.128784],
#         ...,
#         [298.066284, 298.128784, ..., 302.691284, 302.691284],
#         [298.128784, 298.128784, ..., 302.691284, 302.691284]]])
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 -2.698e+06 -2.695e+06 ... 2.693e+06 2.696e+06
#   * y            (y) float64 1.587e+06 1.584e+06 ... -1.584e+06 -1.587e+06
#     spatial_ref  int32 0
# Attributes: (12/15)
#     GRIB_COMMENT:                        (prodType 0, cat 0, subcat 0) [-]
#     GRIB_DISCIPLINE:                     0(Meteorological)
#     GRIB_ELEMENT:                        unknown
#     GRIB_FORECAST_SECONDS:               3600
#     GRIB_IDS:                            CENTER=7 SUBCENTER=0 MASTER_TABLE=2 ...
#     GRIB_PDS_PDTN:                       0
#     ...                                  ...
#     GRIB_SHORT_NAME:                     0-RESERVED
#     GRIB_UNIT:                           [-]
#     GRIB_VALID_TIME:                     1632661200
#     scale_factor:                        1.0
#     add_offset:                          0.0
#     long_name:                           0[-] RESERVED="Reserved"

# %%
rds.rio.crs
# Out:
# CRS.from_wkt('PROJCS["unnamed",GEOGCS["Coordinate System imported from GRIB file",DATUM["unnamed",SPHEROID["Sphere",6371229,0]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Lambert_Conformal_Conic_2SP"],PARAMETER["latitude_of_origin",38.5],PARAMETER["central_meridian",-97.5],PARAMETER["standard_parallel_1",38.5],PARAMETER["standard_parallel_2",38.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["Metre",1],AXIS["Easting",EAST],AXIS["Northing",NORTH]]')

# %%
rds.rio.estimate_utm_crs()
# Out:
# CRS.from_epsg(32614)

# %%
test_rds = rds.rio.write_crs('epsg:32614')

# %%
test_rds = test_rds.rename(x='lon', y='lat')

# %%
test_rds.rio.set_spatial_dims(
    x_dim="lon",
    y_dim="lat"
#     inplace=True,
)
# Out:
# <xarray.DataArray (band: 1, lat: 1059, lon: 1799)>
# array([[[288.691284, 288.691284, ..., 286.066284, 286.128784],
#         [288.691284, 288.691284, ..., 286.066284, 286.128784],
#         ...,
#         [298.066284, 298.128784, ..., 302.691284, 302.691284],
#         [298.128784, 298.128784, ..., 302.691284, 302.691284]]])
# Coordinates:
#   * band         (band) int32 1
#   * lon          (lon) float64 -2.698e+06 -2.695e+06 ... 2.693e+06 2.696e+06
#   * lat          (lat) float64 1.587e+06 1.584e+06 ... -1.584e+06 -1.587e+06
#     spatial_ref  int32 0
# Attributes: (12/15)
#     GRIB_COMMENT:                        (prodType 0, cat 0, subcat 0) [-]
#     GRIB_DISCIPLINE:                     0(Meteorological)
#     GRIB_ELEMENT:                        unknown
#     GRIB_FORECAST_SECONDS:               3600
#     GRIB_IDS:                            CENTER=7 SUBCENTER=0 MASTER_TABLE=2 ...
#     GRIB_PDS_PDTN:                       0
#     ...                                  ...
#     GRIB_SHORT_NAME:                     0-RESERVED
#     GRIB_UNIT:                           [-]
#     GRIB_VALID_TIME:                     1632661200
#     scale_factor:                        1.0
#     add_offset:                          0.0
#     long_name:                           0[-] RESERVED="Reserved"

# %%
test_rds.lon
# Out:
# <xarray.DataArray 'lon' (lon: 1799)>
# array([-2697520.142522, -2694520.142522, -2691520.142522, ...,  2690479.857478,
#         2693479.857478,  2696479.857478])
# Coordinates:
#   * lon          (lon) float64 -2.698e+06 -2.695e+06 ... 2.693e+06 2.696e+06
#     spatial_ref  int32 0

# %%
test_rds.spatial_ref
# Out:
# <xarray.DataArray 'spatial_ref' ()>
# array(0)
# Coordinates:
#     spatial_ref  int32 0
# Attributes: (12/18)
#     crs_wkt:                           PROJCS["WGS 84 / UTM zone 14N",GEOGCS[...
#     semi_major_axis:                   6378137.0
#     semi_minor_axis:                   6356752.314245179
#     inverse_flattening:                298.257223563
#     reference_ellipsoid_name:          WGS 84
#     longitude_of_prime_meridian:       0.0
#     ...                                ...
#     longitude_of_central_meridian:     -99.0
#     false_easting:                     500000.0
#     false_northing:                    0.0
#     scale_factor_at_central_meridian:  0.9996
#     spatial_ref:                       PROJCS["WGS 84 / UTM zone 14N",GEOGCS[...
#     GeoTransform:                      -2699020.14252193 3000.0 0.0 1588193.8...

# %%
test_rds.x
# Out:
# <xarray.DataArray (band: 1, y: 1059, x: 1799)>
# [1905141 values with dtype=float64]
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 -2.698e+06 -2.695e+06 ... 2.693e+06 2.696e+06
#   * y            (y) float64 1.587e+06 1.584e+06 ... -1.584e+06 -1.587e+06
#     spatial_ref  int32 0
# Attributes: (12/15)
#     GRIB_COMMENT:                        (prodType 0, cat 0, subcat 0) [-]
#     GRIB_DISCIPLINE:                     0(Meteorological)
#     GRIB_ELEMENT:                        unknown
#     GRIB_FORECAST_SECONDS:               3600
#     GRIB_IDS:                            CENTER=7 SUBCENTER=0 MASTER_TABLE=2 ...
#     GRIB_PDS_PDTN:                       0
#     ...                                  ...
#     GRIB_SHORT_NAME:                     0-RESERVED
#     GRIB_UNIT:                           [-]
#     GRIB_VALID_TIME:                     1632661200
#     scale_factor:                        1.0
#     add_offset:                          0.0
#     long_name:                           0[-] RESERVED="Reserved"

# %%
test_rds.plot()

# %%
(minx, miny, maxx, maxy) = sample_bbox

# %%
sample_bbox
# Out:
# [-110.65854661288282,
#  41.97915969028358,
#  -110.6561333871172,
#  41.980960309574755]

# %%
test_rds.rio.crs
# Out:
# CRS.from_epsg(4326)

# %%
test_rds.rio.clip_box(
        minx=minx-1,
        miny=miny-1,
        maxx=maxx+1,
        maxy=maxy+1,
        crs="EPSG:4326",
    )
# Out:
# ---------------------------------------------------------------------------
# OneDimensionalRaster                      Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 test_rds.rio.clip_box(
#       2         minx=minx-1,
#       3         miny=miny-1,
#       4         maxx=maxx+1,
#       5         maxy=maxy+1,
#       6         crs="EPSG:4326",
#       7     )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\rioxarray\raster_array.py:839, in RasterArray.clip_box(self, minx, miny, maxx, maxy, auto_expand, auto_expand_limit, crs)
#     835         raise NoDataInBounds(
#     836             f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     837         )
#     838     if cl_array.rio.width == 1 or cl_array.rio.height == 1:
# --> 839         raise OneDimensionalRaster(
#     840             "At least one of the clipped raster x,y coordinates"
#     841             " has only one point."
#     842             f"{_get_data_var_message(self._obj)}"
#     843         )
#     845 # make sure correct attributes preserved & projection added
#     846 _add_attrs_proj(cl_array, self._obj)
#
# OneDimensionalRaster: At least one of the clipped raster x,y coordinates has only one point.

# %%
rds2 = (
    rioxarray.open_rasterio(file.name).rio.clip_box(
        minx=minx,
        miny=miny,
        maxx=maxx,
        maxy=maxy,
#         crs="EPSG:4326",
    )
    )
# Out:
# ---------------------------------------------------------------------------
# OneDimensionalRaster                      Traceback (most recent call last)
# Cell In[77], line 2
#       1 rds2 = (
# ----> 2     rioxarray.open_rasterio(file.name).rio.clip_box(
#       3         minx=minx,
#       4         miny=miny,
#       5         maxx=maxx,
#       6         maxy=maxy,
#       7 #         crs="EPSG:4326",
#       8     )
#       9     )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\rioxarray\raster_array.py:839, in RasterArray.clip_box(self, minx, miny, maxx, maxy, auto_expand, auto_expand_limit, crs)
#     835         raise NoDataInBounds(
#     836             f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     837         )
#     838     if cl_array.rio.width == 1 or cl_array.rio.height == 1:
# --> 839         raise OneDimensionalRaster(
#     840             "At least one of the clipped raster x,y coordinates"
#     841             " has only one point."
#     842             f"{_get_data_var_message(self._obj)}"
#     843         )
#     845 # make sure correct attributes preserved & projection added
#     846 _add_attrs_proj(cl_array, self._obj)
#
# OneDimensionalRaster: At least one of the clipped raster x,y coordinates has only one point.

# %%
rds.plot()

# %%
big_pull.rio.estimate_utm_crs()
# Out:
# CRS.from_epsg(32614)

# %% [markdown]
# Can I pull in the whole grib2?

# %%
big_pull = rioxarray.open_rasterio(url, parse_coordinates=True)

# %%
big_pull_changed = big_pull.rio.write_crs(32614)

# %%
big_pull_changed.rio.crs
# Out:
# CRS.from_epsg(32614)

# %%
big_pull_changed.coords
# Out:
# Coordinates:
#   * band         (band) int32 1 2 3 4 5 6 7 8 ... 702 703 704 705 706 707 708
#   * x            (x) float64 -2.698e+06 -2.695e+06 ... 2.693e+06 2.696e+06
#   * y            (y) float64 1.587e+06 1.584e+06 ... -1.584e+06 -1.587e+06
#     spatial_ref  int32 0

# %%
big_pull_changed.rio.set_spatial_dims(
    x_dim="x",
    y_dim="y",
    inplace=True,
).rio.write_coordinate_system(inplace=True)
# Out:
# <xarray.DataArray (band: 708, y: 1059, x: 1799)>
# [1348839828 values with dtype=float64]
# Coordinates:
#   * band         (band) int32 1 2 3 4 5 6 7 8 ... 702 703 704 705 706 707 708
#   * x            (x) float64 -2.698e+06 -2.695e+06 ... 2.693e+06 2.696e+06
#   * y            (y) float64 1.587e+06 1.584e+06 ... -1.584e+06 -1.587e+06
#     spatial_ref  int32 0
# Attributes: (12/15)
#     GRIB_COMMENT:                        (prodType 0, cat 3, subcat 5) [-]
#     GRIB_DISCIPLINE:                     0(Meteorological)
#     GRIB_ELEMENT:                        unknown
#     GRIB_FORECAST_SECONDS:               3600
#     GRIB_IDS:                            CENTER=7 SUBCENTER=0 MASTER_TABLE=2 ...
#     GRIB_PDS_PDTN:                       0
#     ...                                  ...
#     GRIB_SHORT_NAME:                     5000-RESERVED
#     GRIB_UNIT:                           [-]
#     GRIB_VALID_TIME:                     1632661200
#     scale_factor:                        1.0
#     add_offset:                          0.0
#     long_name:                           ('HGT:50 mb:1 hour fcst', 'TMP:50 mb...

# %%
transform = rio.

# %%
big_pull_changed.rio.wr

# %% [markdown]
# This stuff can likely be deleted

# %%
import xarray as xr

# %%
# Constants for creating the full URL
blob_container = "https://noaahrrr.blob.core.windows.net/hrrr"
sector = "conus"
yesterday = date.today() - timedelta(days=1)
cycle = 12          # noon
forecast_hour = 1   # offset from cycle time
product = "wrfsfcf" # 2D surface levels

# Put it all together
file_path = f"hrrr.t{cycle:02}z.{product}{forecast_hour:02}.grib2"
url = f"{blob_container}/hrrr.{yesterday:%Y%m%d}/{sector}/{file_path}"

print(url)
# Out:
# https://noaahrrr.blob.core.windows.net/hrrr/hrrr.20230206/conus/hrrr.t12z.wrfsfcf01.grib2

# %%
# Fetch the idx file by appending the .idx file extension to our already formatted URL
r = requests.get(f"{url}.idx")
idx = r.text.splitlines()

# Take a peek at the content of the index
print(*idx[0:10], sep="\n")
# Out:
# 1:0:d=2023020612:REFC:entire atmosphere:1 hour fcst:
# 2:294585:d=2023020612:RETOP:cloud top:1 hour fcst:
# 3:422792:d=2023020612:var discipline=0 center=7 local_table=1 parmcat=16 parm=201:entire atmosphere:1 hour fcst:
# 4:795117:d=2023020612:VIL:entire atmosphere:1 hour fcst:
# 5:1003224:d=2023020612:VIS:surface:1 hour fcst:
# 6:2462896:d=2023020612:REFD:1000 m above ground:1 hour fcst:
# 7:2623507:d=2023020612:REFD:4000 m above ground:1 hour fcst:
# 8:2733189:d=2023020612:REFD:263 K level:1 hour fcst:
# 9:2883435:d=2023020612:GUST:surface:1 hour fcst:
# 10:4219834:d=2023020612:UGRD:250 mb:1 hour fcst:

# %%
idx
# Out:
# ['1:0:d=2023020612:REFC:entire atmosphere:1 hour fcst:',
#  '2:294585:d=2023020612:RETOP:cloud top:1 hour fcst:',
#  '3:422792:d=2023020612:var discipline=0 center=7 local_table=1 parmcat=16 parm=201:entire atmosphere:1 hour fcst:',
#  '4:795117:d=2023020612:VIL:entire atmosphere:1 hour fcst:',
#  '5:1003224:d=2023020612:VIS:surface:1 hour fcst:',
#  '6:2462896:d=2023020612:REFD:1000 m above ground:1 hour fcst:',
#  '7:2623507:d=2023020612:REFD:4000 m above ground:1 hour fcst:',
#  '8:2733189:d=2023020612:REFD:263 K level:1 hour fcst:',
#  '9:2883435:d=2023020612:GUST:surface:1 hour fcst:',
#  '10:4219834:d=2023020612:UGRD:250 mb:1 hour fcst:',
#  '11:5005056:d=2023020612:VGRD:250 mb:1 hour fcst:',
#  '12:5762941:d=2023020612:UGRD:300 mb:1 hour fcst:',
#  '13:6536869:d=2023020612:VGRD:300 mb:1 hour fcst:',
#  '14:7286060:d=2023020612:HGT:500 mb:1 hour fcst:',
#  '15:8014662:d=2023020612:TMP:500 mb:1 hour fcst:',
#  '16:8561882:d=2023020612:DPT:500 mb:1 hour fcst:',
#  '17:9461884:d=2023020612:UGRD:500 mb:1 hour fcst:',
#  '18:10050413:d=2023020612:VGRD:500 mb:1 hour fcst:',
#  '19:10653255:d=2023020612:HGT:700 mb:1 hour fcst:',
#  '20:11372972:d=2023020612:TMP:700 mb:1 hour fcst:',
#  '21:11934343:d=2023020612:DPT:700 mb:1 hour fcst:',
#  '22:12932086:d=2023020612:DZDT:700 mb:1 hour fcst:',
#  '23:13922551:d=2023020612:UGRD:700 mb:1 hour fcst:',
#  '24:14536642:d=2023020612:VGRD:700 mb:1 hour fcst:',
#  '25:15152205:d=2023020612:HGT:850 mb:1 hour fcst:',
#  '26:15895110:d=2023020612:TMP:850 mb:1 hour fcst:',
#  '27:16485833:d=2023020612:DPT:850 mb:1 hour fcst:',
#  '28:17643456:d=2023020612:UGRD:850 mb:1 hour fcst:',
#  '29:18280485:d=2023020612:VGRD:850 mb:1 hour fcst:',
#  '30:18929013:d=2023020612:TMP:925 mb:1 hour fcst:',
#  '31:19540545:d=2023020612:DPT:925 mb:1 hour fcst:',
#  '32:20723962:d=2023020612:UGRD:925 mb:1 hour fcst:',
#  '33:21373122:d=2023020612:VGRD:925 mb:1 hour fcst:',
#  '34:22027829:d=2023020612:TMP:1000 mb:1 hour fcst:',
#  '35:22660714:d=2023020612:DPT:1000 mb:1 hour fcst:',
#  '36:23840471:d=2023020612:UGRD:1000 mb:1 hour fcst:',
#  '37:24497379:d=2023020612:VGRD:1000 mb:1 hour fcst:',
#  '38:25142615:d=2023020612:MAXUVV:100-1000 mb above ground:0-1 hour max fcst:',
#  '39:25861177:d=2023020612:MAXDVV:100-1000 mb above ground:0-1 hour max fcst:',
#  '40:26592808:d=2023020612:DZDT:0.5-0.8 sigma layer:0-1 hour ave fcst:',
#  '41:27256719:d=2023020612:MSLMA:mean sea level:1 hour fcst:',
#  '42:27895564:d=2023020612:HGT:1000 mb:1 hour fcst:',
#  '43:28654143:d=2023020612:MAXREF:1000 m above ground:0-1 hour max fcst:',
#  '44:28910180:d=2023020612:REFD:263 K level:0-1 hour max fcst:',
#  '45:29146780:d=2023020612:MXUPHL:5000-2000 m above ground:0-1 hour max fcst:',
#  '46:29261065:d=2023020612:MNUPHL:5000-2000 m above ground:0-1 hour min fcst:',
#  '47:29353163:d=2023020612:MXUPHL:2000-0 m above ground:0-1 hour max fcst:',
#  '48:29453437:d=2023020612:MNUPHL:2000-0 m above ground:0-1 hour min fcst:',
#  '49:29670130:d=2023020612:MXUPHL:3000-0 m above ground:0-1 hour max fcst:',
#  '50:29770332:d=2023020612:MNUPHL:3000-0 m above ground:0-1 hour min fcst:',
#  '51:30005438:d=2023020612:RELV:2000-0 m above ground:0-1 hour max fcst:',
#  '52:32058832:d=2023020612:RELV:1000-0 m above ground:0-1 hour max fcst:',
#  '53:34440380:d=2023020612:HAIL:entire atmosphere:0-1 hour max fcst:',
#  '54:34631565:d=2023020612:HAIL:0.1 sigma level:0-1 hour max fcst:',
#  '55:34673126:d=2023020612:HAIL:surface:0-1 hour max fcst:',
#  '56:34676280:d=2023020612:TCOLG:entire atmosphere (considered as a single layer):0-1 hour max fcst:',
#  '57:34716946:d=2023020612:LTNGSD:1 m above ground:1 hour fcst:',
#  '58:34719592:d=2023020612:LTNGSD:2 m above ground:1 hour fcst:',
#  '59:34795658:d=2023020612:LTNG:entire atmosphere:1 hour fcst:',
#  '60:34836340:d=2023020612:UGRD:80 m above ground:1 hour fcst:',
#  '61:36038147:d=2023020612:VGRD:80 m above ground:1 hour fcst:',
#  '62:37272375:d=2023020612:PRES:surface:1 hour fcst:',
#  '63:38787666:d=2023020612:HGT:surface:1 hour fcst:',
#  '64:40941361:d=2023020612:TMP:surface:1 hour fcst:',
#  '65:42355521:d=2023020612:ASNOW:surface:0-1 hour acc fcst:',
#  '66:42570411:d=2023020612:MSTAV:0 m underground:1 hour fcst:',
#  '67:43888714:d=2023020612:CNWAT:surface:1 hour fcst:',
#  '68:44111597:d=2023020612:WEASD:surface:1 hour fcst:',
#  '69:44980919:d=2023020612:SNOWC:surface:1 hour fcst:',
#  '70:45191408:d=2023020612:SNOD:surface:1 hour fcst:',
#  '71:45892346:d=2023020612:TMP:2 m above ground:1 hour fcst:',
#  '72:47175567:d=2023020612:POT:2 m above ground:1 hour fcst:',
#  '73:48458165:d=2023020612:SPFH:2 m above ground:1 hour fcst:',
#  '74:49916124:d=2023020612:DPT:2 m above ground:1 hour fcst:',
#  '75:51219770:d=2023020612:RH:2 m above ground:1 hour fcst:',
#  '76:52904907:d=2023020612:MASSDEN:8 m above ground:1 hour fcst:',
#  '77:53588749:d=2023020612:UGRD:10 m above ground:1 hour fcst:',
#  '78:55970364:d=2023020612:VGRD:10 m above ground:1 hour fcst:',
#  '79:58351979:d=2023020612:WIND:10 m above ground:0-1 hour max fcst:',
#  '80:59686286:d=2023020612:MAXUW:10 m above ground:0-1 hour max fcst:',
#  '81:61113470:d=2023020612:MAXVW:10 m above ground:0-1 hour max fcst:',
#  '82:62540167:d=2023020612:CPOFP:surface:1 hour fcst:',
#  '83:62622936:d=2023020612:PRATE:surface:1 hour fcst:',
#  '84:62679868:d=2023020612:APCP:surface:0-1 hour acc fcst:',
#  '85:63013333:d=2023020612:WEASD:surface:0-1 hour acc fcst:',
#  '86:63216133:d=2023020612:FROZR:surface:0-1 hour acc fcst:',
#  '87:63271061:d=2023020612:FRZR:surface:0-1 hour acc fcst:',
#  '88:63459236:d=2023020612:SSRUN:surface:0-1 hour acc fcst:',
#  '89:63460742:d=2023020612:BGRUN:surface:0-1 hour acc fcst:',
#  '90:63461086:d=2023020612:CSNOW:surface:1 hour fcst:',
#  '91:63498584:d=2023020612:CICEP:surface:1 hour fcst:',
#  '92:63499326:d=2023020612:CFRZR:surface:1 hour fcst:',
#  '93:63506723:d=2023020612:CRAIN:surface:1 hour fcst:',
#  '94:63532430:d=2023020612:SFCR:surface:1 hour fcst:',
#  '95:65457840:d=2023020612:FRICV:surface:1 hour fcst:',
#  '96:66718669:d=2023020612:SHTFL:surface:1 hour fcst:',
#  '97:68054515:d=2023020612:LHTFL:surface:1 hour fcst:',
#  '98:69205370:d=2023020612:VEG:surface:1 hour fcst:',
#  '99:70585450:d=2023020612:var discipline=2 center=7 local_table=1 parmcat=0 parm=231:surface:1 hour fcst:',
#  '100:71701587:d=2023020612:var discipline=2 center=7 local_table=1 parmcat=0 parm=232:surface:1 hour fcst:',
#  '101:72578521:d=2023020612:LAI:surface:1 hour fcst:',
#  '102:73256016:d=2023020612:GFLUX:surface:1 hour fcst:',
#  '103:73837979:d=2023020612:VGTYP:surface:1 hour fcst:',
#  '104:74624570:d=2023020612:LFTX:500-1000 mb:1 hour fcst:',
#  '105:75684192:d=2023020612:CAPE:surface:1 hour fcst:',
#  '106:75903359:d=2023020612:CIN:surface:1 hour fcst:',
#  '107:76188139:d=2023020612:PWAT:entire atmosphere (considered as a single layer):1 hour fcst:',
#  '108:77007295:d=2023020612:AOTK:entire atmosphere (considered as a single layer):1 hour fcst:',
#  '109:77832148:d=2023020612:COLMD:entire atmosphere (considered as a single layer):1 hour fcst:',
#  '110:78836118:d=2023020612:TCOLW:entire atmosphere:1 hour fcst:',
#  '111:79728126:d=2023020612:TCOLI:entire atmosphere:1 hour fcst:',
#  '112:81114126:d=2023020612:TCDC:boundary layer cloud layer:1 hour fcst:',
#  '113:81922687:d=2023020612:LCDC:low cloud layer:1 hour fcst:',
#  '114:82858547:d=2023020612:MCDC:middle cloud layer:1 hour fcst:',
#  '115:83226464:d=2023020612:HCDC:high cloud layer:1 hour fcst:',
#  '116:83558591:d=2023020612:TCDC:entire atmosphere:1 hour fcst:',
#  '117:84479786:d=2023020612:HGT:cloud ceiling:1 hour fcst:',
#  '118:85697378:d=2023020612:HGT:cloud base:1 hour fcst:',
#  '119:88031859:d=2023020612:PRES:cloud base:1 hour fcst:',
#  '120:89119265:d=2023020612:PRES:cloud top:1 hour fcst:',
#  '121:89729874:d=2023020612:HGT:cloud top:1 hour fcst:',
#  '122:90818148:d=2023020612:ULWRF:top of atmosphere:1 hour fcst:',
#  '123:92709747:d=2023020612:DSWRF:surface:1 hour fcst:',
#  '124:93411924:d=2023020612:DLWRF:surface:1 hour fcst:',
#  '125:95551307:d=2023020612:USWRF:surface:1 hour fcst:',
#  '126:96069027:d=2023020612:ULWRF:surface:1 hour fcst:',
#  '127:97754042:d=2023020612:CFNSF:surface:1 hour fcst:',
#  '128:97756372:d=2023020612:VBDSF:surface:1 hour fcst:',
#  '129:98505181:d=2023020612:VDDSF:surface:1 hour fcst:',
#  '130:99220491:d=2023020612:USWRF:top of atmosphere:1 hour fcst:',
#  '131:99924658:d=2023020612:HLCY:3000-0 m above ground:1 hour fcst:',
#  '132:101195743:d=2023020612:HLCY:1000-0 m above ground:1 hour fcst:',
#  '133:102449418:d=2023020612:USTM:0-6000 m above ground:1 hour fcst:',
#  '134:103481334:d=2023020612:VSTM:0-6000 m above ground:1 hour fcst:',
#  '135:104491714:d=2023020612:VUCSH:0-1000 m above ground:1 hour fcst:',
#  '136:106873329:d=2023020612:VVCSH:0-1000 m above ground:1 hour fcst:',
#  '137:109254944:d=2023020612:VUCSH:0-6000 m above ground:1 hour fcst:',
#  '138:111874701:d=2023020612:VVCSH:0-6000 m above ground:1 hour fcst:',
#  '139:114494458:d=2023020612:HGT:0C isotherm:1 hour fcst:',
#  '140:116610333:d=2023020612:RH:0C isotherm:1 hour fcst:',
#  '141:117428451:d=2023020612:PRES:0C isotherm:1 hour fcst:',
#  '142:118397996:d=2023020612:HGT:highest tropospheric freezing level:1 hour fcst:',
#  '143:119202199:d=2023020612:RH:highest tropospheric freezing level:1 hour fcst:',
#  '144:119938560:d=2023020612:PRES:highest tropospheric freezing level:1 hour fcst:',
#  '145:120808295:d=2023020612:HGT:263 K level:1 hour fcst:',
#  '146:121533164:d=2023020612:HGT:253 K level:1 hour fcst:',
#  '147:122202968:d=2023020612:4LFTX:180-0 mb above ground:1 hour fcst:',
#  '148:123129647:d=2023020612:CAPE:180-0 mb above ground:1 hour fcst:',
#  '149:123382350:d=2023020612:CIN:180-0 mb above ground:1 hour fcst:',
#  '150:123657501:d=2023020612:HPBL:surface:1 hour fcst:',
#  '151:126528899:d=2023020612:HGT:level of adiabatic condensation from sfc:1 hour fcst:',
#  '152:129397393:d=2023020612:CAPE:90-0 mb above ground:1 hour fcst:',
#  '153:129584016:d=2023020612:CIN:90-0 mb above ground:1 hour fcst:',
#  '154:129842383:d=2023020612:CAPE:255-0 mb above ground:1 hour fcst:',
#  '155:130056393:d=2023020612:CIN:255-0 mb above ground:1 hour fcst:',
#  '156:130287235:d=2023020612:HGT:equilibrium level:1 hour fcst:',
#  '157:132242528:d=2023020612:PLPL:255-0 mb above ground:1 hour fcst:',
#  '158:133271176:d=2023020612:CAPE:0-3000 m above ground:1 hour fcst:',
#  '159:133850247:d=2023020612:HGT:level of free convection:1 hour fcst:',
#  '160:136232492:d=2023020612:var discipline=0 center=7 local_table=1 parmcat=7 parm=204:surface:1 hour fcst:',
#  '161:136624935:d=2023020612:var discipline=0 center=7 local_table=1 parmcat=7 parm=206:0-500 m above ground:1 hour fcst:',
#  '162:138648182:d=2023020612:LAYTH:261 K level - 256 K level:1 hour fcst:',
#  '163:139980018:d=2023020612:var discipline=0 center=7 local_table=1 parmcat=7 parm=205:0-3000 m above ground:1 hour fcst:',
#  '164:140474973:d=2023020612:RHPW:entire atmosphere:1 hour fcst:',
#  '165:141649088:d=2023020612:LAND:surface:1 hour fcst:',
#  '166:141701059:d=2023020612:ICEC:surface:1 hour fcst:',
#  '167:141721232:d=2023020612:SBT123:top of atmosphere:1 hour fcst:',
#  '168:143195846:d=2023020612:SBT124:top of atmosphere:1 hour fcst:',
#  '169:145599769:d=2023020612:SBT113:top of atmosphere:1 hour fcst:',
#  '170:146946649:d=2023020612:SBT114:top of atmosphere:1 hour fcst:']

# %%
# You can see it has a 1-indexed base line number, staring byte position, date, variable, atmosphere level,
# and forecast description. The lines are colon-delimited. 

# Let's grab surface temperature `TMP:surface`.
sfc_temp_idx = [l for l in idx if ":TMP:surface" in l][0].split(":")
print("Surface temp line:", sfc_temp_idx)

# Pluck the byte offset from this line, plus the beginning offset of the next line
line_num = int(sfc_temp_idx[0])
range_start = sfc_temp_idx[1]

# The line number values are 1-indexed, so we don't need to increment it to get the next list index,
# but check we're not already reading the last line
next_line = idx[line_num].split(':') if line_num < len(idx) else None

# Pluck the start of the next byte offset, or nothing if we were on the last line
range_end = next_line[1] if next_line else None

print(f"Byte range: {range_start}-{range_end}")
# Out:
# Surface temp line: ['64', '40941361', 'd=2023020612', 'TMP', 'surface', '1 hour fcst', '']
# Byte range: 40941361-42355521

# %%
import tempfile
file = tempfile.NamedTemporaryFile(prefix="tmp_", delete=False)

headers = {"Range": f"bytes={range_start}-{range_end}"}
resp = requests.get(url, headers=headers, stream=True)

with file as f:
    f.write(resp.content)

# %%
file.name
# Out:
# 'C:\\Users\\nacnu\\AppData\\Local\\Temp\\tmp_sovhowcx'

# %%
rioxarray.open_rasterio()

# %%
ds = xr.open_dataset(file.name, engine='cfgrib', 
                     backend_kwargs={'indexpath':''})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 ds = xr.open_dataset(file.name, engine='cfgrib',
#       2                      backend_kwargs={'indexpath':''})
#
# File ~\anaconda3\envs\capstone\lib\site-packages\xarray\backends\api.py:527, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     524 if engine is None:
#     525     engine = plugins.guess_engine(filename_or_obj)
# --> 527 backend = plugins.get_backend(engine)
#     529 decoders = _resolve_decoders_kwargs(
#     530     decode_cf,
#     531     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     537     decode_coords=decode_coords,
#     538 )
#     540 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
#
# File ~\anaconda3\envs\capstone\lib\site-packages\xarray\backends\plugins.py:185, in get_backend(engine)
#     183     engines = list_engines()
#     184     if engine not in engines:
# --> 185         raise ValueError(
#     186             f"unrecognized engine {engine} must be one of: {list(engines)}"
#     187         )
#     188     backend = engines[engine]
#     189 elif isinstance(engine, type) and issubclass(engine, BackendEntrypoint):
#
# ValueError: unrecognized engine cfgrib must be one of: ['scipy', 'rasterio', 'store']

# %% [markdown]
# ## Trying from aws

# %%
sector = "conus"
cycle = 12  # noon
forecast_hour = 1  # offset from cycle time
product = "wrfprsf"  # 3D Pressure Levels
sample_date = "20190826"  # August 8 2019

file_path = f"hrrr.t{cycle:02}z.{product}{forecast_hour:02}.grib2"
url = f"https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.{sample_date}/{sector}/{file_path}"
print(f"Full URL: {url}")

r = requests.get(f"{url}.idx")
idx = r.text.splitlines()
# Out:
# Full URL: https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20190826/conus/hrrr.t12z.wrfprsf01.grib2

# %%
idx
# Out:
# ['1:0:d=2019082612:HGT:50 mb:1 hour fcst:',
#  '2:702620:d=2019082612:TMP:50 mb:1 hour fcst:',
#  '3:1252887:d=2019082612:RH:50 mb:1 hour fcst:',
#  '4:1384611:d=2019082612:DPT:50 mb:1 hour fcst:',
#  '5:1384799:d=2019082612:SPFH:50 mb:1 hour fcst:',
#  '6:2124174:d=2019082612:VVEL:50 mb:1 hour fcst:',
#  '7:2405768:d=2019082612:UGRD:50 mb:1 hour fcst:',
#  '8:2968791:d=2019082612:VGRD:50 mb:1 hour fcst:',
#  '9:3530253:d=2019082612:ABSV:50 mb:1 hour fcst:',
#  '10:4095921:d=2019082612:CLMR:50 mb:1 hour fcst:',
#  '11:4096109:d=2019082612:CIMIXR:50 mb:1 hour fcst:',
#  '12:4096297:d=2019082612:RWMR:50 mb:1 hour fcst:',
#  '13:4096485:d=2019082612:SNMR:50 mb:1 hour fcst:',
#  '14:4100934:d=2019082612:GRLE:50 mb:1 hour fcst:',
#  '15:4101179:d=2019082612:HGT:75 mb:1 hour fcst:',
#  '16:4819410:d=2019082612:TMP:75 mb:1 hour fcst:',
#  '17:5383148:d=2019082612:RH:75 mb:1 hour fcst:',
#  '18:5791591:d=2019082612:DPT:75 mb:1 hour fcst:',
#  '19:5793470:d=2019082612:SPFH:75 mb:1 hour fcst:',
#  '20:6401334:d=2019082612:VVEL:75 mb:1 hour fcst:',
#  '21:6748626:d=2019082612:UGRD:75 mb:1 hour fcst:',
#  '22:7303324:d=2019082612:VGRD:75 mb:1 hour fcst:',
#  '23:7865918:d=2019082612:ABSV:75 mb:1 hour fcst:',
#  '24:8449531:d=2019082612:CLMR:75 mb:1 hour fcst:',
#  '25:8449719:d=2019082612:CIMIXR:75 mb:1 hour fcst:',
#  '26:8452093:d=2019082612:RWMR:75 mb:1 hour fcst:',
#  '27:8452281:d=2019082612:SNMR:75 mb:1 hour fcst:',
#  '28:8461456:d=2019082612:GRLE:75 mb:1 hour fcst:',
#  '29:8465233:d=2019082612:HGT:100 mb:1 hour fcst:',
#  '30:9187725:d=2019082612:TMP:100 mb:1 hour fcst:',
#  '31:9750065:d=2019082612:RH:100 mb:1 hour fcst:',
#  '32:10267384:d=2019082612:DPT:100 mb:1 hour fcst:',
#  '33:10279256:d=2019082612:SPFH:100 mb:1 hour fcst:',
#  '34:10912128:d=2019082612:VVEL:100 mb:1 hour fcst:',
#  '35:11299585:d=2019082612:UGRD:100 mb:1 hour fcst:',
#  '36:11878654:d=2019082612:VGRD:100 mb:1 hour fcst:',
#  '37:12445193:d=2019082612:ABSV:100 mb:1 hour fcst:',
#  '38:13032126:d=2019082612:CLMR:100 mb:1 hour fcst:',
#  '39:13032314:d=2019082612:CIMIXR:100 mb:1 hour fcst:',
#  '40:13033480:d=2019082612:RWMR:100 mb:1 hour fcst:',
#  '41:13033668:d=2019082612:SNMR:100 mb:1 hour fcst:',
#  '42:13035998:d=2019082612:GRLE:100 mb:1 hour fcst:',
#  '43:13041121:d=2019082612:HGT:125 mb:1 hour fcst:',
#  '44:13783098:d=2019082612:TMP:125 mb:1 hour fcst:',
#  '45:14353483:d=2019082612:RH:125 mb:1 hour fcst:',
#  '46:14925220:d=2019082612:DPT:125 mb:1 hour fcst:',
#  '47:15163095:d=2019082612:SPFH:125 mb:1 hour fcst:',
#  '48:15908679:d=2019082612:VVEL:125 mb:1 hour fcst:',
#  '49:16366261:d=2019082612:UGRD:125 mb:1 hour fcst:',
#  '50:16955939:d=2019082612:VGRD:125 mb:1 hour fcst:',
#  '51:17534345:d=2019082612:ABSV:125 mb:1 hour fcst:',
#  '52:17925745:d=2019082612:CLMR:125 mb:1 hour fcst:',
#  '53:17925933:d=2019082612:CIMIXR:125 mb:1 hour fcst:',
#  '54:17938528:d=2019082612:RWMR:125 mb:1 hour fcst:',
#  '55:17938716:d=2019082612:SNMR:125 mb:1 hour fcst:',
#  '56:17951443:d=2019082612:GRLE:125 mb:1 hour fcst:',
#  '57:17956923:d=2019082612:HGT:150 mb:1 hour fcst:',
#  '58:18696841:d=2019082612:TMP:150 mb:1 hour fcst:',
#  '59:19251667:d=2019082612:RH:150 mb:1 hour fcst:',
#  '60:19862175:d=2019082612:DPT:150 mb:1 hour fcst:',
#  '61:20323340:d=2019082612:SPFH:150 mb:1 hour fcst:',
#  '62:21273592:d=2019082612:VVEL:150 mb:1 hour fcst:',
#  '63:21783242:d=2019082612:UGRD:150 mb:1 hour fcst:',
#  '64:22376423:d=2019082612:VGRD:150 mb:1 hour fcst:',
#  '65:22959146:d=2019082612:ABSV:150 mb:1 hour fcst:',
#  '66:23408125:d=2019082612:CLMR:150 mb:1 hour fcst:',
#  '67:23408313:d=2019082612:CIMIXR:150 mb:1 hour fcst:',
#  '68:23436754:d=2019082612:RWMR:150 mb:1 hour fcst:',
#  '69:23436942:d=2019082612:SNMR:150 mb:1 hour fcst:',
#  '70:23465732:d=2019082612:GRLE:150 mb:1 hour fcst:',
#  '71:23473796:d=2019082612:HGT:175 mb:1 hour fcst:',
#  '72:24207587:d=2019082612:TMP:175 mb:1 hour fcst:',
#  '73:24756718:d=2019082612:RH:175 mb:1 hour fcst:',
#  '74:25409613:d=2019082612:DPT:175 mb:1 hour fcst:',
#  '75:26000948:d=2019082612:SPFH:175 mb:1 hour fcst:',
#  '76:26724187:d=2019082612:VVEL:175 mb:1 hour fcst:',
#  '77:27273845:d=2019082612:UGRD:175 mb:1 hour fcst:',
#  '78:27871172:d=2019082612:VGRD:175 mb:1 hour fcst:',
#  '79:28466317:d=2019082612:ABSV:175 mb:1 hour fcst:',
#  '80:28951914:d=2019082612:CLMR:175 mb:1 hour fcst:',
#  '81:28952102:d=2019082612:CIMIXR:175 mb:1 hour fcst:',
#  '82:28978465:d=2019082612:RWMR:175 mb:1 hour fcst:',
#  '83:28978653:d=2019082612:SNMR:175 mb:1 hour fcst:',
#  '84:29020660:d=2019082612:GRLE:175 mb:1 hour fcst:',
#  '85:29035074:d=2019082612:HGT:200 mb:1 hour fcst:',
#  '86:29774302:d=2019082612:TMP:200 mb:1 hour fcst:',
#  '87:30313182:d=2019082612:RH:200 mb:1 hour fcst:',
#  '88:31003363:d=2019082612:DPT:200 mb:1 hour fcst:',
#  '89:31698043:d=2019082612:SPFH:200 mb:1 hour fcst:',
#  '90:32588124:d=2019082612:VVEL:200 mb:1 hour fcst:',
#  '91:33160037:d=2019082612:UGRD:200 mb:1 hour fcst:',
#  '92:33759210:d=2019082612:VGRD:200 mb:1 hour fcst:',
#  '93:34360822:d=2019082612:ABSV:200 mb:1 hour fcst:',
#  '94:34868457:d=2019082612:CLMR:200 mb:1 hour fcst:',
#  '95:34868645:d=2019082612:CIMIXR:200 mb:1 hour fcst:',
#  '96:34907131:d=2019082612:RWMR:200 mb:1 hour fcst:',
#  '97:34907319:d=2019082612:SNMR:200 mb:1 hour fcst:',
#  '98:34961231:d=2019082612:GRLE:200 mb:1 hour fcst:',
#  '99:34979732:d=2019082612:HGT:225 mb:1 hour fcst:',
#  '100:35714937:d=2019082612:TMP:225 mb:1 hour fcst:',
#  '101:36231446:d=2019082612:RH:225 mb:1 hour fcst:',
#  '102:36934045:d=2019082612:DPT:225 mb:1 hour fcst:',
#  '103:37721099:d=2019082612:SPFH:225 mb:1 hour fcst:',
#  '104:38751037:d=2019082612:VVEL:225 mb:1 hour fcst:',
#  '105:39333844:d=2019082612:UGRD:225 mb:1 hour fcst:',
#  '106:39932307:d=2019082612:VGRD:225 mb:1 hour fcst:',
#  '107:40537362:d=2019082612:ABSV:225 mb:1 hour fcst:',
#  '108:41046059:d=2019082612:CLMR:225 mb:1 hour fcst:',
#  '109:41046247:d=2019082612:CIMIXR:225 mb:1 hour fcst:',
#  '110:41095716:d=2019082612:RWMR:225 mb:1 hour fcst:',
#  '111:41095904:d=2019082612:SNMR:225 mb:1 hour fcst:',
#  '112:41161149:d=2019082612:GRLE:225 mb:1 hour fcst:',
#  '113:41182858:d=2019082612:HGT:250 mb:1 hour fcst:',
#  '114:41914210:d=2019082612:TMP:250 mb:1 hour fcst:',
#  '115:42424254:d=2019082612:RH:250 mb:1 hour fcst:',
#  '116:43138744:d=2019082612:DPT:250 mb:1 hour fcst:',
#  '117:43940668:d=2019082612:SPFH:250 mb:1 hour fcst:',
#  '118:45095464:d=2019082612:VVEL:250 mb:1 hour fcst:',
#  '119:45686743:d=2019082612:UGRD:250 mb:1 hour fcst:',
#  '120:46283723:d=2019082612:VGRD:250 mb:1 hour fcst:',
#  '121:46888481:d=2019082612:ABSV:250 mb:1 hour fcst:',
#  '122:47396268:d=2019082612:CLMR:250 mb:1 hour fcst:',
#  '123:47396620:d=2019082612:CIMIXR:250 mb:1 hour fcst:',
#  '124:47456153:d=2019082612:RWMR:250 mb:1 hour fcst:',
#  '125:47459623:d=2019082612:SNMR:250 mb:1 hour fcst:',
#  '126:47537007:d=2019082612:GRLE:250 mb:1 hour fcst:',
#  '127:47560929:d=2019082612:HGT:275 mb:1 hour fcst:',
#  '128:48287667:d=2019082612:TMP:275 mb:1 hour fcst:',
#  '129:48810137:d=2019082612:RH:275 mb:1 hour fcst:',
#  '130:49530385:d=2019082612:DPT:275 mb:1 hour fcst:',
#  '131:50342033:d=2019082612:SPFH:275 mb:1 hour fcst:',
#  '132:51113977:d=2019082612:VVEL:275 mb:1 hour fcst:',
#  '133:51713734:d=2019082612:UGRD:275 mb:1 hour fcst:',
#  '134:52312147:d=2019082612:VGRD:275 mb:1 hour fcst:',
#  '135:52910600:d=2019082612:ABSV:275 mb:1 hour fcst:',
#  '136:53418379:d=2019082612:CLMR:275 mb:1 hour fcst:',
#  '137:53420798:d=2019082612:CIMIXR:275 mb:1 hour fcst:',
#  '138:53445518:d=2019082612:RWMR:275 mb:1 hour fcst:',
#  '139:53450912:d=2019082612:SNMR:275 mb:1 hour fcst:',
#  '140:53537679:d=2019082612:GRLE:275 mb:1 hour fcst:',
#  '141:53563810:d=2019082612:HGT:300 mb:1 hour fcst:',
#  '142:54286721:d=2019082612:TMP:300 mb:1 hour fcst:',
#  '143:54808833:d=2019082612:RH:300 mb:1 hour fcst:',
#  '144:55508126:d=2019082612:DPT:300 mb:1 hour fcst:',
#  '145:56307861:d=2019082612:SPFH:300 mb:1 hour fcst:',
#  '146:57132811:d=2019082612:VVEL:300 mb:1 hour fcst:',
#  '147:57735880:d=2019082612:UGRD:300 mb:1 hour fcst:',
#  '148:58331610:d=2019082612:VGRD:300 mb:1 hour fcst:',
#  '149:58927833:d=2019082612:ABSV:300 mb:1 hour fcst:',
#  '150:59425764:d=2019082612:CLMR:300 mb:1 hour fcst:',
#  '151:59428819:d=2019082612:CIMIXR:300 mb:1 hour fcst:',
#  '152:59485898:d=2019082612:RWMR:300 mb:1 hour fcst:',
#  '153:59491431:d=2019082612:SNMR:300 mb:1 hour fcst:',
#  '154:59583591:d=2019082612:GRLE:300 mb:1 hour fcst:',
#  '155:59611185:d=2019082612:HGT:325 mb:1 hour fcst:',
#  '156:60316282:d=2019082612:TMP:325 mb:1 hour fcst:',
#  '157:60838710:d=2019082612:RH:325 mb:1 hour fcst:',
#  '158:61546091:d=2019082612:DPT:325 mb:1 hour fcst:',
#  '159:62347603:d=2019082612:SPFH:325 mb:1 hour fcst:',
#  '160:63234191:d=2019082612:VVEL:325 mb:1 hour fcst:',
#  '161:63841432:d=2019082612:UGRD:325 mb:1 hour fcst:',
#  '162:64438078:d=2019082612:VGRD:325 mb:1 hour fcst:',
#  '163:65034093:d=2019082612:ABSV:325 mb:1 hour fcst:',
#  '164:65532499:d=2019082612:CLMR:325 mb:1 hour fcst:',
#  '165:65537200:d=2019082612:CIMIXR:325 mb:1 hour fcst:',
#  '166:65634694:d=2019082612:RWMR:325 mb:1 hour fcst:',
#  '167:65638944:d=2019082612:SNMR:325 mb:1 hour fcst:',
#  '168:65733909:d=2019082612:GRLE:325 mb:1 hour fcst:',
#  '169:65762815:d=2019082612:HGT:350 mb:1 hour fcst:',
#  '170:66463933:d=2019082612:TMP:350 mb:1 hour fcst:',
#  '171:67000336:d=2019082612:RH:350 mb:1 hour fcst:',
#  '172:67708785:d=2019082612:DPT:350 mb:1 hour fcst:',
#  '173:68513806:d=2019082612:SPFH:350 mb:1 hour fcst:',
#  '174:69486648:d=2019082612:VVEL:350 mb:1 hour fcst:',
#  '175:70096555:d=2019082612:UGRD:350 mb:1 hour fcst:',
#  '176:70691243:d=2019082612:VGRD:350 mb:1 hour fcst:',
#  '177:71286789:d=2019082612:ABSV:350 mb:1 hour fcst:',
#  '178:71782888:d=2019082612:CLMR:350 mb:1 hour fcst:',
#  '179:71790522:d=2019082612:CIMIXR:350 mb:1 hour fcst:',
#  '180:71874543:d=2019082612:RWMR:350 mb:1 hour fcst:',
#  '181:71880298:d=2019082612:SNMR:350 mb:1 hour fcst:',
#  '182:71977156:d=2019082612:GRLE:350 mb:1 hour fcst:',
#  '183:72007224:d=2019082612:HGT:375 mb:1 hour fcst:',
#  '184:72706938:d=2019082612:TMP:375 mb:1 hour fcst:',
#  '185:73246328:d=2019082612:RH:375 mb:1 hour fcst:',
#  '186:73951361:d=2019082612:DPT:375 mb:1 hour fcst:',
#  '187:74766895:d=2019082612:SPFH:375 mb:1 hour fcst:',
#  '188:75809918:d=2019082612:VVEL:375 mb:1 hour fcst:',
#  '189:76423287:d=2019082612:UGRD:375 mb:1 hour fcst:',
#  '190:77016433:d=2019082612:VGRD:375 mb:1 hour fcst:',
#  '191:77609396:d=2019082612:ABSV:375 mb:1 hour fcst:',
#  '192:78103345:d=2019082612:CLMR:375 mb:1 hour fcst:',
#  '193:78114925:d=2019082612:CIMIXR:375 mb:1 hour fcst:',
#  '194:78188533:d=2019082612:RWMR:375 mb:1 hour fcst:',
#  '195:78195957:d=2019082612:SNMR:375 mb:1 hour fcst:',
#  '196:78294661:d=2019082612:GRLE:375 mb:1 hour fcst:',
#  '197:78325985:d=2019082612:HGT:400 mb:1 hour fcst:',
#  '198:79026258:d=2019082612:TMP:400 mb:1 hour fcst:',
#  '199:79564791:d=2019082612:RH:400 mb:1 hour fcst:',
#  '200:80263039:d=2019082612:DPT:400 mb:1 hour fcst:',
#  '201:81096477:d=2019082612:SPFH:400 mb:1 hour fcst:',
#  '202:82210854:d=2019082612:VVEL:400 mb:1 hour fcst:',
#  '203:82824068:d=2019082612:UGRD:400 mb:1 hour fcst:',
#  '204:83416234:d=2019082612:VGRD:400 mb:1 hour fcst:',
#  '205:84007516:d=2019082612:ABSV:400 mb:1 hour fcst:',
#  '206:84501134:d=2019082612:CLMR:400 mb:1 hour fcst:',
#  '207:84517229:d=2019082612:CIMIXR:400 mb:1 hour fcst:',
#  '208:84580549:d=2019082612:RWMR:400 mb:1 hour fcst:',
#  '209:84589357:d=2019082612:SNMR:400 mb:1 hour fcst:',
#  '210:84689424:d=2019082612:GRLE:400 mb:1 hour fcst:',
#  '211:84722122:d=2019082612:HGT:425 mb:1 hour fcst:',
#  '212:85421050:d=2019082612:TMP:425 mb:1 hour fcst:',
#  '213:85959937:d=2019082612:RH:425 mb:1 hour fcst:',
#  '214:86657862:d=2019082612:DPT:425 mb:1 hour fcst:',
#  '215:87530898:d=2019082612:SPFH:425 mb:1 hour fcst:',
#  '216:88741493:d=2019082612:VVEL:425 mb:1 hour fcst:',
#  '217:89366757:d=2019082612:UGRD:425 mb:1 hour fcst:',
#  '218:89958956:d=2019082612:VGRD:425 mb:1 hour fcst:',
#  '219:90551361:d=2019082612:ABSV:425 mb:1 hour fcst:',
#  '220:91045223:d=2019082612:CLMR:425 mb:1 hour fcst:',
#  '221:91067013:d=2019082612:CIMIXR:425 mb:1 hour fcst:',
#  '222:91122025:d=2019082612:RWMR:425 mb:1 hour fcst:',
#  '223:91133042:d=2019082612:SNMR:425 mb:1 hour fcst:',
#  '224:91232132:d=2019082612:GRLE:425 mb:1 hour fcst:',
#  '225:91267042:d=2019082612:HGT:450 mb:1 hour fcst:',
#  '226:91962269:d=2019082612:TMP:450 mb:1 hour fcst:',
#  '227:92509317:d=2019082612:RH:450 mb:1 hour fcst:',
#  '228:93213318:d=2019082612:DPT:450 mb:1 hour fcst:',
#  '229:94115626:d=2019082612:SPFH:450 mb:1 hour fcst:',
#  '230:95411975:d=2019082612:VVEL:450 mb:1 hour fcst:',
#  '231:96048955:d=2019082612:UGRD:450 mb:1 hour fcst:',
#  '232:96641768:d=2019082612:VGRD:450 mb:1 hour fcst:',
#  '233:97233555:d=2019082612:ABSV:450 mb:1 hour fcst:',
#  '234:97733685:d=2019082612:CLMR:450 mb:1 hour fcst:',
#  '235:97760675:d=2019082612:CIMIXR:450 mb:1 hour fcst:',
#  '236:97809109:d=2019082612:RWMR:450 mb:1 hour fcst:',
#  '237:97822087:d=2019082612:SNMR:450 mb:1 hour fcst:',
#  '238:97921437:d=2019082612:GRLE:450 mb:1 hour fcst:',
#  '239:97958776:d=2019082612:HGT:475 mb:1 hour fcst:',
#  '240:98652235:d=2019082612:TMP:475 mb:1 hour fcst:',
#  '241:99196160:d=2019082612:RH:475 mb:1 hour fcst:',
#  '242:99898015:d=2019082612:DPT:475 mb:1 hour fcst:',
#  '243:100811563:d=2019082612:SPFH:475 mb:1 hour fcst:',
#  '244:102168745:d=2019082612:VVEL:475 mb:1 hour fcst:',
#  '245:102806022:d=2019082612:UGRD:475 mb:1 hour fcst:',
#  '246:103399870:d=2019082612:VGRD:475 mb:1 hour fcst:',
#  '247:103990026:d=2019082612:ABSV:475 mb:1 hour fcst:',
#  '248:104485811:d=2019082612:CLMR:475 mb:1 hour fcst:',
#  '249:104521786:d=2019082612:CIMIXR:475 mb:1 hour fcst:',
#  '250:104566262:d=2019082612:RWMR:475 mb:1 hour fcst:',
#  '251:104582457:d=2019082612:SNMR:475 mb:1 hour fcst:',
#  '252:104684188:d=2019082612:GRLE:475 mb:1 hour fcst:',
#  '253:104726544:d=2019082612:HGT:500 mb:1 hour fcst:',
#  '254:105420216:d=2019082612:TMP:500 mb:1 hour fcst:',
#  '255:105965135:d=2019082612:RH:500 mb:1 hour fcst:',
#  '256:106668364:d=2019082612:DPT:500 mb:1 hour fcst:',
#  '257:107597394:d=2019082612:SPFH:500 mb:1 hour fcst:',
#  '258:109040634:d=2019082612:VVEL:500 mb:1 hour fcst:',
#  '259:109677329:d=2019082612:UGRD:500 mb:1 hour fcst:',
#  '260:110271672:d=2019082612:VGRD:500 mb:1 hour fcst:',
#  '261:110861758:d=2019082612:ABSV:500 mb:1 hour fcst:',
#  '262:111362428:d=2019082612:CLMR:500 mb:1 hour fcst:',
#  '263:111415854:d=2019082612:CIMIXR:500 mb:1 hour fcst:',
#  '264:111456108:d=2019082612:RWMR:500 mb:1 hour fcst:',
#  '265:111478812:d=2019082612:SNMR:500 mb:1 hour fcst:',
#  '266:111580980:d=2019082612:GRLE:500 mb:1 hour fcst:',
#  '267:111602873:d=2019082612:HGT:525 mb:1 hour fcst:',
#  '268:112292744:d=2019082612:TMP:525 mb:1 hour fcst:',
#  '269:112850969:d=2019082612:RH:525 mb:1 hour fcst:',
#  '270:113562654:d=2019082612:DPT:525 mb:1 hour fcst:',
#  '271:114520456:d=2019082612:SPFH:525 mb:1 hour fcst:',
#  '272:116048765:d=2019082612:VVEL:525 mb:1 hour fcst:',
#  '273:116686190:d=2019082612:UGRD:525 mb:1 hour fcst:',
#  '274:117281521:d=2019082612:VGRD:525 mb:1 hour fcst:',
#  '275:117865581:d=2019082612:ABSV:525 mb:1 hour fcst:',
#  '276:118372710:d=2019082612:CLMR:525 mb:1 hour fcst:',
#  '277:118433598:d=2019082612:CIMIXR:525 mb:1 hour fcst:',
#  '278:118469634:d=2019082612:RWMR:525 mb:1 hour fcst:',
#  '279:118497909:d=2019082612:SNMR:525 mb:1 hour fcst:',
#  '280:118599735:d=2019082612:GRLE:525 mb:1 hour fcst:',
#  '281:118624378:d=2019082612:HGT:550 mb:1 hour fcst:',
#  '282:119317991:d=2019082612:TMP:550 mb:1 hour fcst:',
#  '283:119873477:d=2019082612:RH:550 mb:1 hour fcst:',
#  '284:120586977:d=2019082612:DPT:550 mb:1 hour fcst:',
#  '285:121540129:d=2019082612:SPFH:550 mb:1 hour fcst:',
#  '286:123111220:d=2019082612:VVEL:550 mb:1 hour fcst:',
#  '287:123737652:d=2019082612:UGRD:550 mb:1 hour fcst:',
#  '288:124332412:d=2019082612:VGRD:550 mb:1 hour fcst:',
#  '289:124915271:d=2019082612:ABSV:550 mb:1 hour fcst:',
#  '290:125419558:d=2019082612:CLMR:550 mb:1 hour fcst:',
#  '291:125490939:d=2019082612:CIMIXR:550 mb:1 hour fcst:',
#  '292:125516741:d=2019082612:RWMR:550 mb:1 hour fcst:',
#  '293:125563228:d=2019082612:SNMR:550 mb:1 hour fcst:',
#  '294:125659777:d=2019082612:GRLE:550 mb:1 hour fcst:',
#  '295:125685107:d=2019082612:HGT:575 mb:1 hour fcst:',
#  '296:126376056:d=2019082612:TMP:575 mb:1 hour fcst:',
#  '297:126932689:d=2019082612:RH:575 mb:1 hour fcst:',
#  '298:127656292:d=2019082612:DPT:575 mb:1 hour fcst:',
#  '299:128630794:d=2019082612:SPFH:575 mb:1 hour fcst:',
#  '300:130273461:d=2019082612:VVEL:575 mb:1 hour fcst:',
#  '301:130902198:d=2019082612:UGRD:575 mb:1 hour fcst:',
#  '302:131498010:d=2019082612:VGRD:575 mb:1 hour fcst:',
#  '303:132084155:d=2019082612:ABSV:575 mb:1 hour fcst:',
#  '304:132596932:d=2019082612:CLMR:575 mb:1 hour fcst:',
#  '305:132676814:d=2019082612:CIMIXR:575 mb:1 hour fcst:',
#  '306:132714678:d=2019082612:RWMR:575 mb:1 hour fcst:',
#  '307:132741700:d=2019082612:SNMR:575 mb:1 hour fcst:',
#  '308:132828655:d=2019082612:GRLE:575 mb:1 hour fcst:',
#  '309:132852809:d=2019082612:HGT:600 mb:1 hour fcst:',
#  '310:133543392:d=2019082612:TMP:600 mb:1 hour fcst:',
#  '311:134097554:d=2019082612:RH:600 mb:1 hour fcst:',
#  '312:134819281:d=2019082612:DPT:600 mb:1 hour fcst:',
#  '313:135764849:d=2019082612:SPFH:600 mb:1 hour fcst:',
#  '314:137431707:d=2019082612:VVEL:600 mb:1 hour fcst:',
#  '315:138060323:d=2019082612:UGRD:600 mb:1 hour fcst:',
#  '316:138650243:d=2019082612:VGRD:600 mb:1 hour fcst:',
#  '317:139236920:d=2019082612:ABSV:600 mb:1 hour fcst:',
#  '318:139745262:d=2019082612:CLMR:600 mb:1 hour fcst:',
#  '319:139829814:d=2019082612:CIMIXR:600 mb:1 hour fcst:',
#  '320:139854113:d=2019082612:RWMR:600 mb:1 hour fcst:',
#  '321:139890207:d=2019082612:SNMR:600 mb:1 hour fcst:',
#  '322:139964417:d=2019082612:GRLE:600 mb:1 hour fcst:',
#  '323:139985403:d=2019082612:HGT:625 mb:1 hour fcst:',
#  '324:140673192:d=2019082612:TMP:625 mb:1 hour fcst:',
#  '325:141230326:d=2019082612:RH:625 mb:1 hour fcst:',
#  '326:141956185:d=2019082612:DPT:625 mb:1 hour fcst:',
#  '327:142903240:d=2019082612:SPFH:625 mb:1 hour fcst:',
#  '328:143931331:d=2019082612:VVEL:625 mb:1 hour fcst:',
#  '329:144563214:d=2019082612:UGRD:625 mb:1 hour fcst:',
#  '330:145153951:d=2019082612:VGRD:625 mb:1 hour fcst:',
#  '331:145743584:d=2019082612:ABSV:625 mb:1 hour fcst:',
#  '332:146261041:d=2019082612:CLMR:625 mb:1 hour fcst:',
#  '333:146346231:d=2019082612:CIMIXR:625 mb:1 hour fcst:',
#  '334:146353332:d=2019082612:RWMR:625 mb:1 hour fcst:',
#  '335:146396180:d=2019082612:SNMR:625 mb:1 hour fcst:',
#  '336:146452477:d=2019082612:GRLE:625 mb:1 hour fcst:',
#  '337:146491132:d=2019082612:HGT:650 mb:1 hour fcst:',
#  '338:147177280:d=2019082612:TMP:650 mb:1 hour fcst:',
#  '339:147733843:d=2019082612:RH:650 mb:1 hour fcst:',
#  '340:148458969:d=2019082612:DPT:650 mb:1 hour fcst:',
#  '341:149398917:d=2019082612:SPFH:650 mb:1 hour fcst:',
#  '342:150443070:d=2019082612:VVEL:650 mb:1 hour fcst:',
#  '343:151078660:d=2019082612:UGRD:650 mb:1 hour fcst:',
#  '344:151670673:d=2019082612:VGRD:650 mb:1 hour fcst:',
#  '345:152253303:d=2019082612:ABSV:650 mb:1 hour fcst:',
#  '346:152768274:d=2019082612:CLMR:650 mb:1 hour fcst:',
#  '347:152852193:d=2019082612:CIMIXR:650 mb:1 hour fcst:',
#  '348:152858902:d=2019082612:RWMR:650 mb:1 hour fcst:',
#  '349:152904807:d=2019082612:SNMR:650 mb:1 hour fcst:',
#  '350:152947826:d=2019082612:GRLE:650 mb:1 hour fcst:',
#  '351:152979914:d=2019082612:HGT:675 mb:1 hour fcst:',
#  '352:153663633:d=2019082612:TMP:675 mb:1 hour fcst:',
#  '353:154223559:d=2019082612:RH:675 mb:1 hour fcst:',
#  '354:154956747:d=2019082612:DPT:675 mb:1 hour fcst:',
#  '355:155927685:d=2019082612:SPFH:675 mb:1 hour fcst:',
#  '356:157009011:d=2019082612:VVEL:675 mb:1 hour fcst:',
#  '357:157649596:d=2019082612:UGRD:675 mb:1 hour fcst:',
#  '358:158244875:d=2019082612:VGRD:675 mb:1 hour fcst:',
#  '359:158831435:d=2019082612:ABSV:675 mb:1 hour fcst:',
#  '360:159353137:d=2019082612:CLMR:675 mb:1 hour fcst:',
#  '361:159430051:d=2019082612:CIMIXR:675 mb:1 hour fcst:',
#  '362:159433175:d=2019082612:RWMR:675 mb:1 hour fcst:',
#  '363:159481990:d=2019082612:SNMR:675 mb:1 hour fcst:',
#  '364:159503249:d=2019082612:GRLE:675 mb:1 hour fcst:',
#  '365:159527356:d=2019082612:HGT:700 mb:1 hour fcst:',
#  '366:160198385:d=2019082612:TMP:700 mb:1 hour fcst:',
#  '367:160758922:d=2019082612:RH:700 mb:1 hour fcst:',
#  '368:161498624:d=2019082612:DPT:700 mb:1 hour fcst:',
#  '369:162483307:d=2019082612:SPFH:700 mb:1 hour fcst:',
#  '370:163601979:d=2019082612:VVEL:700 mb:1 hour fcst:',
#  '371:164247851:d=2019082612:UGRD:700 mb:1 hour fcst:',
#  '372:164842685:d=2019082612:VGRD:700 mb:1 hour fcst:',
#  '373:165431786:d=2019082612:ABSV:700 mb:1 hour fcst:',
#  '374:165950733:d=2019082612:CLMR:700 mb:1 hour fcst:',
#  '375:166027116:d=2019082612:CIMIXR:700 mb:1 hour fcst:',
#  '376:166027941:d=2019082612:RWMR:700 mb:1 hour fcst:',
#  '377:166078758:d=2019082612:SNMR:700 mb:1 hour fcst:',
#  '378:166109461:d=2019082612:GRLE:700 mb:1 hour fcst:',
#  '379:166127831:d=2019082612:HGT:725 mb:1 hour fcst:',
#  '380:166797672:d=2019082612:TMP:725 mb:1 hour fcst:',
#  '381:167360037:d=2019082612:RH:725 mb:1 hour fcst:',
#  '382:168113009:d=2019082612:DPT:725 mb:1 hour fcst:',
#  '383:169116863:d=2019082612:SPFH:725 mb:1 hour fcst:',
#  '384:170279678:d=2019082612:VVEL:725 mb:1 hour fcst:',
#  '385:170930773:d=2019082612:UGRD:725 mb:1 hour fcst:',
#  '386:171529403:d=2019082612:VGRD:725 mb:1 hour fcst:',
#  '387:172122332:d=2019082612:ABSV:725 mb:1 hour fcst:',
#  '388:172648557:d=2019082612:CLMR:725 mb:1 hour fcst:',
#  '389:172726887:d=2019082612:CIMIXR:725 mb:1 hour fcst:',
#  '390:172727447:d=2019082612:RWMR:725 mb:1 hour fcst:',
#  '391:172779607:d=2019082612:SNMR:725 mb:1 hour fcst:',
#  '392:172792790:d=2019082612:GRLE:725 mb:1 hour fcst:',
#  '393:172805308:d=2019082612:HGT:750 mb:1 hour fcst:',
#  '394:173475718:d=2019082612:TMP:750 mb:1 hour fcst:',
#  '395:174040944:d=2019082612:RH:750 mb:1 hour fcst:',
#  '396:174804543:d=2019082612:DPT:750 mb:1 hour fcst:',
#  '397:175829677:d=2019082612:SPFH:750 mb:1 hour fcst:',
#  '398:177044020:d=2019082612:VVEL:750 mb:1 hour fcst:',
#  '399:177700860:d=2019082612:UGRD:750 mb:1 hour fcst:',
#  '400:178302719:d=2019082612:VGRD:750 mb:1 hour fcst:',
#  '401:178901365:d=2019082612:ABSV:750 mb:1 hour fcst:',
#  '402:179429713:d=2019082612:CLMR:750 mb:1 hour fcst:',
#  '403:179510734:d=2019082612:CIMIXR:750 mb:1 hour fcst:',
#  '404:179511089:d=2019082612:RWMR:750 mb:1 hour fcst:',
#  '405:179564746:d=2019082612:SNMR:750 mb:1 hour fcst:',
#  '406:179570618:d=2019082612:GRLE:750 mb:1 hour fcst:',
#  '407:179578663:d=2019082612:HGT:775 mb:1 hour fcst:',
#  '408:180255066:d=2019082612:TMP:775 mb:1 hour fcst:',
#  '409:180817900:d=2019082612:RH:775 mb:1 hour fcst:',
#  '410:181593380:d=2019082612:DPT:775 mb:1 hour fcst:',
#  '411:182627137:d=2019082612:SPFH:775 mb:1 hour fcst:',
#  '412:183883558:d=2019082612:VVEL:775 mb:1 hour fcst:',
#  '413:184546030:d=2019082612:UGRD:775 mb:1 hour fcst:',
#  '414:185150860:d=2019082612:VGRD:775 mb:1 hour fcst:',
#  '415:185753273:d=2019082612:ABSV:775 mb:1 hour fcst:',
#  '416:186287922:d=2019082612:CLMR:775 mb:1 hour fcst:',
#  '417:186382541:d=2019082612:CIMIXR:775 mb:1 hour fcst:',
#  '418:186486748:d=2019082612:RWMR:775 mb:1 hour fcst:',
#  '419:186542248:d=2019082612:SNMR:775 mb:1 hour fcst:',
#  '420:186546164:d=2019082612:GRLE:775 mb:1 hour fcst:',
#  '421:186551013:d=2019082612:HGT:800 mb:1 hour fcst:',
#  '422:187238595:d=2019082612:TMP:800 mb:1 hour fcst:',
#  '423:187808904:d=2019082612:RH:800 mb:1 hour fcst:',
#  '424:188603874:d=2019082612:DPT:800 mb:1 hour fcst:',
#  '425:189639200:d=2019082612:SPFH:800 mb:1 hour fcst:',
#  '426:190946430:d=2019082612:VVEL:800 mb:1 hour fcst:',
#  '427:191615610:d=2019082612:UGRD:800 mb:1 hour fcst:',
#  '428:192226217:d=2019082612:VGRD:800 mb:1 hour fcst:',
#  '429:192833327:d=2019082612:ABSV:800 mb:1 hour fcst:',
#  '430:193380345:d=2019082612:CLMR:800 mb:1 hour fcst:',
#  '431:193492241:d=2019082612:CIMIXR:800 mb:1 hour fcst:',
#  '432:193642315:d=2019082612:RWMR:800 mb:1 hour fcst:',
#  '433:193699757:d=2019082612:SNMR:800 mb:1 hour fcst:',
#  '434:193702314:d=2019082612:GRLE:800 mb:1 hour fcst:',
#  '435:193704809:d=2019082612:HGT:825 mb:1 hour fcst:',
#  '436:194404449:d=2019082612:TMP:825 mb:1 hour fcst:',
#  '437:194980721:d=2019082612:RH:825 mb:1 hour fcst:',
#  '438:195792471:d=2019082612:DPT:825 mb:1 hour fcst:',
#  '439:196833295:d=2019082612:SPFH:825 mb:1 hour fcst:',
#  '440:198177234:d=2019082612:VVEL:825 mb:1 hour fcst:',
#  '441:198839788:d=2019082612:UGRD:825 mb:1 hour fcst:',
#  '442:199454968:d=2019082612:VGRD:825 mb:1 hour fcst:',
#  '443:200065835:d=2019082612:ABSV:825 mb:1 hour fcst:',
#  '444:200607746:d=2019082612:CLMR:825 mb:1 hour fcst:',
#  '445:200743578:d=2019082612:CIMIXR:825 mb:1 hour fcst:',
#  '446:200922434:d=2019082612:RWMR:825 mb:1 hour fcst:',
#  '447:201049662:d=2019082612:SNMR:825 mb:1 hour fcst:',
#  '448:201051383:d=2019082612:GRLE:825 mb:1 hour fcst:',
#  '449:201052842:d=2019082612:HGT:850 mb:1 hour fcst:',
#  '450:201768459:d=2019082612:TMP:850 mb:1 hour fcst:',
#  '451:202352086:d=2019082612:RH:850 mb:1 hour fcst:',
#  '452:203174792:d=2019082612:DPT:850 mb:1 hour fcst:',
#  '453:204217775:d=2019082612:SPFH:850 mb:1 hour fcst:',
#  '454:205592812:d=2019082612:VVEL:850 mb:1 hour fcst:',
#  '455:206260345:d=2019082612:UGRD:850 mb:1 hour fcst:',
#  '456:206881452:d=2019082612:VGRD:850 mb:1 hour fcst:',
#  '457:207494620:d=2019082612:ABSV:850 mb:1 hour fcst:',
#  '458:208041411:d=2019082612:CLMR:850 mb:1 hour fcst:',
#  '459:208210926:d=2019082612:CIMIXR:850 mb:1 hour fcst:',
#  '460:208411165:d=2019082612:RWMR:850 mb:1 hour fcst:',
#  '461:208546791:d=2019082612:SNMR:850 mb:1 hour fcst:',
#  '462:208547329:d=2019082612:GRLE:850 mb:1 hour fcst:',
#  '463:208548153:d=2019082612:HGT:875 mb:1 hour fcst:',
#  '464:209281734:d=2019082612:TMP:875 mb:1 hour fcst:',
#  '465:209873255:d=2019082612:RH:875 mb:1 hour fcst:',
#  '466:210709944:d=2019082612:DPT:875 mb:1 hour fcst:',
#  '467:211760893:d=2019082612:SPFH:875 mb:1 hour fcst:',
#  '468:213174753:d=2019082612:VVEL:875 mb:1 hour fcst:',
#  '469:213844187:d=2019082612:UGRD:875 mb:1 hour fcst:',
#  '470:214467938:d=2019082612:VGRD:875 mb:1 hour fcst:',
#  '471:215090358:d=2019082612:ABSV:875 mb:1 hour fcst:',
#  '472:215636204:d=2019082612:CLMR:875 mb:1 hour fcst:',
#  '473:215832884:d=2019082612:CIMIXR:875 mb:1 hour fcst:',
#  '474:216004199:d=2019082612:RWMR:875 mb:1 hour fcst:',
#  '475:216146908:d=2019082612:SNMR:875 mb:1 hour fcst:',
#  '476:216147223:d=2019082612:GRLE:875 mb:1 hour fcst:',
#  '477:216148274:d=2019082612:HGT:900 mb:1 hour fcst:',
#  '478:216901653:d=2019082612:TMP:900 mb:1 hour fcst:',
#  '479:217496788:d=2019082612:RH:900 mb:1 hour fcst:',
#  '480:218340473:d=2019082612:DPT:900 mb:1 hour fcst:',
#  '481:219381074:d=2019082612:SPFH:900 mb:1 hour fcst:',
#  '482:220826796:d=2019082612:VVEL:900 mb:1 hour fcst:',
#  '483:221493765:d=2019082612:UGRD:900 mb:1 hour fcst:',
#  '484:222119949:d=2019082612:VGRD:900 mb:1 hour fcst:',
#  '485:222743056:d=2019082612:ABSV:900 mb:1 hour fcst:',
#  '486:223292134:d=2019082612:CLMR:900 mb:1 hour fcst:',
#  '487:223526235:d=2019082612:CIMIXR:900 mb:1 hour fcst:',
#  '488:223663277:d=2019082612:RWMR:900 mb:1 hour fcst:',
#  '489:223813006:d=2019082612:SNMR:900 mb:1 hour fcst:',
#  '490:223813356:d=2019082612:GRLE:900 mb:1 hour fcst:',
#  '491:223814462:d=2019082612:HGT:925 mb:1 hour fcst:',
#  '492:224586730:d=2019082612:TMP:925 mb:1 hour fcst:',
#  '493:225195036:d=2019082612:RH:925 mb:1 hour fcst:',
#  '494:226009924:d=2019082612:DPT:925 mb:1 hour fcst:',
#  '495:227049126:d=2019082612:SPFH:925 mb:1 hour fcst:',
#  '496:228514592:d=2019082612:VVEL:925 mb:1 hour fcst:',
#  '497:229164418:d=2019082612:UGRD:925 mb:1 hour fcst:',
#  '498:229792065:d=2019082612:VGRD:925 mb:1 hour fcst:',
#  '499:230416369:d=2019082612:ABSV:925 mb:1 hour fcst:',
#  '500:230965882:d=2019082612:CLMR:925 mb:1 hour fcst:',
#  '501:231167170:d=2019082612:CIMIXR:925 mb:1 hour fcst:',
#  '502:231309098:d=2019082612:RWMR:925 mb:1 hour fcst:',
#  '503:231466746:d=2019082612:SNMR:925 mb:1 hour fcst:',
#  '504:231467040:d=2019082612:GRLE:925 mb:1 hour fcst:',
#  '505:231467987:d=2019082612:HGT:950 mb:1 hour fcst:',
#  '506:232259139:d=2019082612:TMP:950 mb:1 hour fcst:',
#  '507:232879479:d=2019082612:RH:950 mb:1 hour fcst:',
#  '508:233667806:d=2019082612:DPT:950 mb:1 hour fcst:',
#  '509:234709700:d=2019082612:SPFH:950 mb:1 hour fcst:',
#  '510:236176732:d=2019082612:VVEL:950 mb:1 hour fcst:',
#  '511:236813888:d=2019082612:UGRD:950 mb:1 hour fcst:',
#  '512:237441279:d=2019082612:VGRD:950 mb:1 hour fcst:',
#  '513:238064908:d=2019082612:ABSV:950 mb:1 hour fcst:',
#  '514:238612142:d=2019082612:CLMR:950 mb:1 hour fcst:',
#  '515:238796307:d=2019082612:CIMIXR:950 mb:1 hour fcst:',
#  '516:238943026:d=2019082612:RWMR:950 mb:1 hour fcst:',
#  '517:239098848:d=2019082612:SNMR:950 mb:1 hour fcst:',
#  '518:239099149:d=2019082612:GRLE:950 mb:1 hour fcst:',
#  '519:239099856:d=2019082612:HGT:975 mb:1 hour fcst:',
#  '520:239911921:d=2019082612:TMP:975 mb:1 hour fcst:',
#  '521:240540528:d=2019082612:RH:975 mb:1 hour fcst:',
#  '522:241315988:d=2019082612:DPT:975 mb:1 hour fcst:',
#  '523:242348155:d=2019082612:SPFH:975 mb:1 hour fcst:',
#  '524:243811586:d=2019082612:VVEL:975 mb:1 hour fcst:',
#  '525:244431635:d=2019082612:UGRD:975 mb:1 hour fcst:',
#  '526:245050125:d=2019082612:VGRD:975 mb:1 hour fcst:',
#  '527:245671778:d=2019082612:ABSV:975 mb:1 hour fcst:',
#  '528:246212692:d=2019082612:CLMR:975 mb:1 hour fcst:',
#  '529:246396971:d=2019082612:CIMIXR:975 mb:1 hour fcst:',
#  '530:246615822:d=2019082612:RWMR:975 mb:1 hour fcst:',
#  '531:246735845:d=2019082612:SNMR:975 mb:1 hour fcst:',
#  '532:246736098:d=2019082612:GRLE:975 mb:1 hour fcst:',
#  '533:246736768:d=2019082612:TMP:1000 mb:1 hour fcst:',
#  '534:247372871:d=2019082612:RH:1000 mb:1 hour fcst:',
#  '535:248158893:d=2019082612:DPT:1000 mb:1 hour fcst:',
#  '536:249179858:d=2019082612:SPFH:1000 mb:1 hour fcst:',
#  '537:250655781:d=2019082612:VVEL:1000 mb:1 hour fcst:',
#  '538:251237635:d=2019082612:UGRD:1000 mb:1 hour fcst:',
#  '539:251857302:d=2019082612:VGRD:1000 mb:1 hour fcst:',
#  '540:252473999:d=2019082612:ABSV:1000 mb:1 hour fcst:',
#  '541:253009341:d=2019082612:CLMR:1000 mb:1 hour fcst:',
#  '542:253055080:d=2019082612:CIMIXR:1000 mb:1 hour fcst:',
#  '543:253199301:d=2019082612:RWMR:1000 mb:1 hour fcst:',
#  '544:253277642:d=2019082612:SNMR:1000 mb:1 hour fcst:',
#  '545:253341938:d=2019082612:GRLE:1000 mb:1 hour fcst:',
#  '546:253429696:d=2019082612:HGT:1013.2 mb:1 hour fcst:',
#  '547:254266513:d=2019082612:TMP:1013.2 mb:1 hour fcst:',
#  '548:254903977:d=2019082612:RH:1013.2 mb:1 hour fcst:',
#  '549:255693849:d=2019082612:DPT:1013.2 mb:1 hour fcst:',
#  '550:256716741:d=2019082612:SPFH:1013.2 mb:1 hour fcst:',
#  '551:258205441:d=2019082612:VVEL:1013.2 mb:1 hour fcst:',
#  '552:258680643:d=2019082612:UGRD:1013.2 mb:1 hour fcst:',
#  '553:259298574:d=2019082612:VGRD:1013.2 mb:1 hour fcst:',
#  '554:259912279:d=2019082612:ABSV:1013.2 mb:1 hour fcst:',
#  '555:260442024:d=2019082612:CLMR:1013.2 mb:1 hour fcst:',
#  '556:260452193:d=2019082612:CIMIXR:1013.2 mb:1 hour fcst:',
#  '557:260539003:d=2019082612:RWMR:1013.2 mb:1 hour fcst:',
#  '558:260586524:d=2019082612:SNMR:1013.2 mb:1 hour fcst:',
#  '559:260673334:d=2019082612:GRLE:1013.2 mb:1 hour fcst:',
#  '560:260760144:d=2019082612:TSOIL:0-0 m below ground:1 hour fcst:',
#  '561:262758146:d=2019082612:SOILW:0-0 m below ground:1 hour fcst:',
#  '562:264024495:d=2019082612:TSOIL:0.01-0.01 m below ground:1 hour fcst:',
#  '563:266005527:d=2019082612:SOILW:0.01-0.01 m below ground:1 hour fcst:',
#  '564:267274691:d=2019082612:TSOIL:0.04-0.04 m below ground:1 hour fcst:',
#  '565:269245514:d=2019082612:SOILW:0.04-0.04 m below ground:1 hour fcst:',
#  '566:270510726:d=2019082612:TSOIL:0.1-0.1 m below ground:1 hour fcst:',
#  '567:272505821:d=2019082612:SOILW:0.1-0.1 m below ground:1 hour fcst:',
#  '568:273776516:d=2019082612:TSOIL:0.3-0.3 m below ground:1 hour fcst:',
#  '569:275845523:d=2019082612:SOILW:0.3-0.3 m below ground:1 hour fcst:',
#  '570:277127665:d=2019082612:TSOIL:0.6-0.6 m below ground:1 hour fcst:',
#  '571:279224923:d=2019082612:SOILW:0.6-0.6 m below ground:1 hour fcst:',
#  '572:280497564:d=2019082612:TSOIL:1-1 m below ground:1 hour fcst:',
#  '573:282640156:d=2019082612:SOILW:1-1 m below ground:1 hour fcst:',
#  '574:283846585:d=2019082612:TSOIL:1.6-1.6 m below ground:1 hour fcst:',
#  '575:286023137:d=2019082612:SOILW:1.6-1.6 m below ground:1 hour fcst:',
#  '576:287210081:d=2019082612:TSOIL:3-3 m below ground:1 hour fcst:',
#  '577:289052262:d=2019082612:SOILW:3-3 m below ground:1 hour fcst:',
#  '578:289826799:d=2019082612:REFC:entire atmosphere:1 hour fcst:',
#  '579:290340234:d=2019082612:RETOP:cloud top:1 hour fcst:',
#  '580:290577591:d=2019082612:VIL:entire atmosphere:1 hour fcst:',
#  '581:290863590:d=2019082612:VIS:surface:1 hour fcst:',
#  '582:292194001:d=2019082612:REFD:1000 m above ground:1 hour fcst:',
#  '583:292482299:d=2019082612:REFD:4000 m above ground:1 hour fcst:',
#  '584:292663599:d=2019082612:REFD:263 K level:1 hour fcst:',
#  '585:292812270:d=2019082612:GUST:surface:1 hour fcst:',
#  '586:294044365:d=2019082612:MAXUVV:100-1000 mb above ground:0-1 hour max fcst:',
#  '587:294697220:d=2019082612:MAXDVV:100-1000 mb above ground:0-1 hour max fcst:',
#  '588:295322285:d=2019082612:DZDT:0.5-0.8 sigma layer:0-1 hour ave fcst:',
#  '589:295997480:d=2019082612:MSLMA:mean sea level:1 hour fcst:',
#  '590:296601153:d=2019082612:HGT:1000 mb:1 hour fcst:',
#  '591:297294428:d=2019082612:MAXREF:1000 m above ground:0-1 hour max fcst:',
#  '592:297742021:d=2019082612:REFD:263 K level:0-1 hour max fcst:',
#  '593:297972685:d=2019082612:MXUPHL:5000-2000 m above ground:0-1 hour max fcst:',
#  '594:298000626:d=2019082612:MNUPHL:5000-2000 m above ground:0-1 hour min fcst:',
#  '595:298222793:d=2019082612:MXUPHL:2000-0 m above ground:0-1 hour max fcst:',
#  '596:298303489:d=2019082612:MNUPHL:2000-0 m above ground:0-1 hour min fcst:',
#  '597:298371682:d=2019082612:MXUPHL:3000-0 m above ground:0-1 hour max fcst:',
#  '598:298478246:d=2019082612:MNUPHL:3000-0 m above ground:0-1 hour min fcst:',
#  '599:298546439:d=2019082612:RELV:2000-0 m above ground:0-1 hour max fcst:',
#  '600:300526024:d=2019082612:RELV:1000-0 m above ground:0-1 hour max fcst:',
#  '601:302861341:d=2019082612:HAIL:entire atmosphere:0-1 hour max fcst:',
#  '602:303068480:d=2019082612:HAIL:0.1 sigma level:0-1 hour max fcst:',
#  '603:303069457:d=2019082612:TCOLG:entire atmosphere (considered as a single layer):0-1 hour max fcst:',
#  '604:303129920:d=2019082612:LTNG:entire atmosphere:1 hour fcst:',
#  '605:303171018:d=2019082612:UGRD:80 m above ground:1 hour fcst:',
#  '606:304320995:d=2019082612:VGRD:80 m above ground:1 hour fcst:',
#  '607:305502590:d=2019082612:PRES:surface:1 hour fcst:',
#  '608:307089448:d=2019082612:HGT:surface:1 hour fcst:',
#  '609:309324225:d=2019082612:TMP:surface:1 hour fcst:',
#  '610:310694021:d=2019082612:ASNOW:surface:0-1 hour acc fcst:',
#  '611:310694888:d=2019082612:MSTAV:0 m underground:1 hour fcst:',
#  '612:312152696:d=2019082612:CNWAT:surface:1 hour fcst:',
#  '613:312266514:d=2019082612:WEASD:surface:1 hour fcst:',
#  '614:312267655:d=2019082612:SNOWC:surface:1 hour fcst:',
#  '615:312268540:d=2019082612:SNOD:surface:1 hour fcst:',
#  '616:312269615:d=2019082612:TMP:2 m above ground:1 hour fcst:',
#  '617:313493945:d=2019082612:POT:2 m above ground:1 hour fcst:',
#  '618:314638568:d=2019082612:SPFH:2 m above ground:1 hour fcst:',
#  '619:316045118:d=2019082612:DPT:2 m above ground:1 hour fcst:',
#  '620:317094911:d=2019082612:RH:2 m above ground:1 hour fcst:',
#  '621:318589353:d=2019082612:UGRD:10 m above ground:1 hour fcst:',
#  '622:319781280:d=2019082612:VGRD:10 m above ground:1 hour fcst:',
#  '623:320968402:d=2019082612:WIND:10 m above ground:0-1 hour max fcst:',
#  '624:322190882:d=2019082612:MAXUW:10 m above ground:0-1 hour max fcst:',
#  '625:323519640:d=2019082612:MAXVW:10 m above ground:0-1 hour max fcst:',
#  '626:324819288:d=2019082612:CPOFP:surface:1 hour fcst:',
#  '627:324982832:d=2019082612:PRATE:surface:1 hour fcst:',
#  '628:325075554:d=2019082612:APCP:surface:0-1 hour acc fcst:',
#  '629:325372665:d=2019082612:WEASD:surface:0-1 hour acc fcst:',
#  '630:325376515:d=2019082612:FROZR:surface:0-1 hour acc fcst:',
#  '631:325377399:d=2019082612:FRZR:surface:0-1 hour acc fcst:',
#  '632:325378414:d=2019082612:SSRUN:surface:0-1 hour acc fcst:',
#  '633:325405317:d=2019082612:BGRUN:surface:0-1 hour acc fcst:',
#  '634:325405845:d=2019082612:CSNOW:surface:1 hour fcst:',
#  '635:325406033:d=2019082612:CICEP:surface:1 hour fcst:',
#  '636:325406221:d=2019082612:CFRZR:surface:1 hour fcst:',
#  '637:325406409:d=2019082612:CRAIN:surface:1 hour fcst:',
#  '638:325493183:d=2019082612:SFCR:surface:1 hour fcst:',
#  '639:327332640:d=2019082612:FRICV:surface:1 hour fcst:',
#  '640:328505171:d=2019082612:SHTFL:surface:1 hour fcst:',
#  '641:329793131:d=2019082612:LHTFL:surface:1 hour fcst:',
#  '642:330471238:d=2019082612:GFLUX:surface:1 hour fcst:',
#  '643:331483135:d=2019082612:VGTYP:surface:1 hour fcst:',
#  '644:332264314:d=2019082612:LFTX:500-1000 mb:1 hour fcst:',
#  '645:333145490:d=2019082612:CAPE:surface:1 hour fcst:',
#  '646:333661168:d=2019082612:CIN:surface:1 hour fcst:',
#  '647:333945115:d=2019082612:PWAT:entire atmosphere (considered as a single layer):1 hour fcst:',
#  '648:334953239:d=2019082612:LCDC:low cloud layer:1 hour fcst:',
#  '649:335609323:d=2019082612:MCDC:middle cloud layer:1 hour fcst:',
#  '650:335907276:d=2019082612:HCDC:high cloud layer:1 hour fcst:',
#  '651:336170398:d=2019082612:TCDC:entire atmosphere:1 hour fcst:',
#  '652:336902192:d=2019082612:PRES:cloud base:1 hour fcst:',
#  '653:337654042:d=2019082612:HGT:cloud base:1 hour fcst:',
#  '654:338835132:d=2019082612:HGT:cloud ceiling:1 hour fcst:',
#  '655:340179051:d=2019082612:PRES:cloud top:1 hour fcst:',
#  '656:340920648:d=2019082612:HGT:cloud top:1 hour fcst:',
#  '657:342164217:d=2019082612:ULWRF:top of atmosphere:1 hour fcst:',
#  '658:344107218:d=2019082612:DSWRF:surface:1 hour fcst:',
#  '659:345804197:d=2019082612:DLWRF:surface:1 hour fcst:',
#  '660:347891688:d=2019082612:USWRF:surface:1 hour fcst:',
#  '661:349041336:d=2019082612:ULWRF:surface:1 hour fcst:',
#  '662:350841098:d=2019082612:VBDSF:surface:1 hour fcst:',
#  '663:352651975:d=2019082612:VDDSF:surface:1 hour fcst:',
#  '664:354419600:d=2019082612:USWRF:top of atmosphere:1 hour fcst:',
#  '665:356023087:d=2019082612:HLCY:3000-0 m above ground:1 hour fcst:',
#  '666:357204416:d=2019082612:HLCY:1000-0 m above ground:1 hour fcst:',
#  '667:359101619:d=2019082612:USTM:0-6000 m above ground:1 hour fcst:',
#  '668:360175397:d=2019082612:VSTM:0-6000 m above ground:1 hour fcst:',
#  '669:361221133:d=2019082612:VUCSH:0-1000 m above ground:1 hour fcst:',
#  '670:362486901:d=2019082612:VVCSH:0-1000 m above ground:1 hour fcst:',
#  '671:363751894:d=2019082612:VUCSH:0-6000 m above ground:1 hour fcst:',
#  '672:364895278:d=2019082612:VVCSH:0-6000 m above ground:1 hour fcst:',
#  '673:366056079:d=2019082612:HGT:0C isotherm:1 hour fcst:',
#  '674:368167955:d=2019082612:RH:0C isotherm:1 hour fcst:',
#  '675:368842265:d=2019082612:PRES:0C isotherm:1 hour fcst:',
#  '676:369541740:d=2019082612:HGT:highest tropospheric freezing level:1 hour fcst:',
#  '677:370264891:d=2019082612:RH:highest tropospheric freezing level:1 hour fcst:',
#  '678:370938995:d=2019082612:PRES:highest tropospheric freezing level:1 hour fcst:',
#  '679:371623330:d=2019082612:HGT:263 K level:1 hour fcst:',
#  '680:372299850:d=2019082612:HGT:253 K level:1 hour fcst:',
#  '681:372903095:d=2019082612:4LFTX:180-0 mb above ground:1 hour fcst:',
#  '682:373804783:d=2019082612:CAPE:180-0 mb above ground:1 hour fcst:',
#  '683:374459955:d=2019082612:CIN:180-0 mb above ground:1 hour fcst:',
#  '684:374833357:d=2019082612:HPBL:surface:1 hour fcst:',
#  '685:377763388:d=2019082612:HGT:level of adiabatic condensation from sfc:1 hour fcst:',
#  '686:380500487:d=2019082612:CAPE:90-0 mb above ground:1 hour fcst:',
#  '687:381001209:d=2019082612:CIN:90-0 mb above ground:1 hour fcst:',
#  '688:381626797:d=2019082612:CAPE:255-0 mb above ground:1 hour fcst:',
#  '689:382293177:d=2019082612:CIN:255-0 mb above ground:1 hour fcst:',
#  '690:382666518:d=2019082612:HGT:equilibrium level:1 hour fcst:',
#  '691:384943346:d=2019082612:PLPL:255-0 mb above ground:1 hour fcst:',
#  '692:386153997:d=2019082612:RHPW:entire atmosphere:1 hour fcst:',
#  '693:387271112:d=2019082612:LAND:surface:1 hour fcst:',
#  '694:387321588:d=2019082612:ICEC:surface:1 hour fcst:',
#  '695:387321776:d=2019082612:SBT123:top of atmosphere:1 hour fcst:',
#  '696:388806068:d=2019082612:SBT124:top of atmosphere:1 hour fcst:',
#  '697:390449746:d=2019082612:SBT113:top of atmosphere:1 hour fcst:',
#  '698:391812546:d=2019082612:SBT114:top of atmosphere:1 hour fcst:']

# %%
# You can see it has a 1-indexed base line number, staring byte position, date, variable, atmosphere level,
# and forecast description. The lines are colon-delimited. 

# Let's grab surface temperature `TMP:surface`.
sfc_temp_idx = [l for l in idx if ":TMP:surface" in l][0].split(":")
print("Surface temp line:", sfc_temp_idx)

# Pluck the byte offset from this line, plus the beginning offset of the next line
line_num = int(sfc_temp_idx[0])
range_start = sfc_temp_idx[1]

# The line number values are 1-indexed, so we don't need to increment it to get the next list index,
# but check we're not already reading the last line
next_line = idx[line_num].split(':') if line_num < len(idx) else None

# Pluck the start of the next byte offset, or nothing if we were on the last line
range_end = next_line[1] if next_line else None

print(f"Byte range: {range_start}-{range_end}")
# Out:
# Surface temp line: ['609', '309324225', 'd=2019082612', 'TMP', 'surface', '1 hour fcst', '']
# Byte range: 309324225-310694021

# %%
# trying to find other things that might help...
any_surface_data = [l for l in idx if ":surface" in l]
# print("Surface precipitation line:", sfc_precipitation_idx)

# %%
any_surface_data
# Out:
# ['581:290863590:d=2019082612:VIS:surface:1 hour fcst:',
#  '585:292812270:d=2019082612:GUST:surface:1 hour fcst:',
#  '607:305502590:d=2019082612:PRES:surface:1 hour fcst:',
#  '608:307089448:d=2019082612:HGT:surface:1 hour fcst:',
#  '609:309324225:d=2019082612:TMP:surface:1 hour fcst:',
#  '610:310694021:d=2019082612:ASNOW:surface:0-1 hour acc fcst:',
#  '612:312152696:d=2019082612:CNWAT:surface:1 hour fcst:',
#  '613:312266514:d=2019082612:WEASD:surface:1 hour fcst:',
#  '614:312267655:d=2019082612:SNOWC:surface:1 hour fcst:',
#  '615:312268540:d=2019082612:SNOD:surface:1 hour fcst:',
#  '626:324819288:d=2019082612:CPOFP:surface:1 hour fcst:',
#  '627:324982832:d=2019082612:PRATE:surface:1 hour fcst:',
#  '628:325075554:d=2019082612:APCP:surface:0-1 hour acc fcst:',
#  '629:325372665:d=2019082612:WEASD:surface:0-1 hour acc fcst:',
#  '630:325376515:d=2019082612:FROZR:surface:0-1 hour acc fcst:',
#  '631:325377399:d=2019082612:FRZR:surface:0-1 hour acc fcst:',
#  '632:325378414:d=2019082612:SSRUN:surface:0-1 hour acc fcst:',
#  '633:325405317:d=2019082612:BGRUN:surface:0-1 hour acc fcst:',
#  '634:325405845:d=2019082612:CSNOW:surface:1 hour fcst:',
#  '635:325406033:d=2019082612:CICEP:surface:1 hour fcst:',
#  '636:325406221:d=2019082612:CFRZR:surface:1 hour fcst:',
#  '637:325406409:d=2019082612:CRAIN:surface:1 hour fcst:',
#  '638:325493183:d=2019082612:SFCR:surface:1 hour fcst:',
#  '639:327332640:d=2019082612:FRICV:surface:1 hour fcst:',
#  '640:328505171:d=2019082612:SHTFL:surface:1 hour fcst:',
#  '641:329793131:d=2019082612:LHTFL:surface:1 hour fcst:',
#  '642:330471238:d=2019082612:GFLUX:surface:1 hour fcst:',
#  '643:331483135:d=2019082612:VGTYP:surface:1 hour fcst:',
#  '645:333145490:d=2019082612:CAPE:surface:1 hour fcst:',
#  '646:333661168:d=2019082612:CIN:surface:1 hour fcst:',
#  '658:344107218:d=2019082612:DSWRF:surface:1 hour fcst:',
#  '659:345804197:d=2019082612:DLWRF:surface:1 hour fcst:',
#  '660:347891688:d=2019082612:USWRF:surface:1 hour fcst:',
#  '661:349041336:d=2019082612:ULWRF:surface:1 hour fcst:',
#  '662:350841098:d=2019082612:VBDSF:surface:1 hour fcst:',
#  '663:352651975:d=2019082612:VDDSF:surface:1 hour fcst:',
#  '684:374833357:d=2019082612:HPBL:surface:1 hour fcst:',
#  '693:387271112:d=2019082612:LAND:surface:1 hour fcst:',
#  '694:387321588:d=2019082612:ICEC:surface:1 hour fcst:']

# %% [markdown]
# - I want PRES (its surface pressure in Pa)
# - I want TMP (surface temp in K)
# - maybe SNOD (snow depth in m)
# - I want GUST (wind gust in m/s)
# - I want PRATE (precipitation rate in kg/m^2s)

# %%
sfc_temp_idx = [l for l in any_surface_data if ":TMP:surface" in l][0].split(":")

# %%
sfc_temp_idx
# Out:
# ['609', '309324225', 'd=2019082612', 'TMP', 'surface', '1 hour fcst', '']

# %%
# Pluck the byte offset from this line, plus the beginning offset of the next line
line_num = int(sfc_temp_idx[0])
range_start = sfc_temp_idx[1]

# The line number values are 1-indexed, so we don't need to increment it to get the next list index,
# but check we're not already reading the last line
next_line = idx[line_num].split(':') if line_num < len(idx) else None

# Pluck the start of the next byte offset, or nothing if we were on the last line
range_end = next_line[1] if next_line else None

print(f"Byte range: {range_start}-{range_end}")
# Out:
# Byte range: 309324225-310694021

# %%
import tempfile
file = tempfile.NamedTemporaryFile(prefix="delete_later_", delete=False)

headers = {"Range": f"bytes={range_start}-{range_end}"}
resp = requests.get(url, headers=headers, stream=True)

with file as f:
    f.write(resp.content)

# %%
rds = rioxarray.open_rasterio(file.name)

# %%
rds
# Out:
# <xarray.DataArray (band: 1, y: 1059, x: 1799)>
# [1905141 values with dtype=float64]
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 -2.698e+06 -2.695e+06 ... 2.693e+06 2.696e+06
#   * y            (y) float64 1.587e+06 1.584e+06 ... -1.584e+06 -1.587e+06
#     spatial_ref  int32 0
# Attributes: (12/15)
#     GRIB_COMMENT:                        (prodType 0, cat 0, subcat 0) [-]
#     GRIB_DISCIPLINE:                     0(Meteorological)
#     GRIB_ELEMENT:                        unknown
#     GRIB_FORECAST_SECONDS:               3600
#     GRIB_IDS:                            CENTER=7 SUBCENTER=0 MASTER_TABLE=2 ...
#     GRIB_PDS_PDTN:                       0
#     ...                                  ...
#     GRIB_SHORT_NAME:                     0-RESERVED
#     GRIB_UNIT:                           [-]
#     GRIB_VALID_TIME:                     1566824400
#     scale_factor:                        1.0
#     add_offset:                          0.0
#     long_name:                           0[-] RESERVED="Reserved"

# %%
rds.t.plot.hist(edgecolor="white")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 rds.t.plot.hist(edgecolor="white")
#       2 plt.show()
#
# File ~\anaconda3\envs\capstone\lib\site-packages\xarray\core\common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'DataArray' object has no attribute 't'

# %%
import tempfile
file = tempfile.NamedTemporaryFile(prefix="tmp_", delete=False)

headers = {"Range": f"bytes={range_start}-{range_end}"}
resp = requests.get(url, headers=headers, stream=True)

with file as f:
    f.write(resp.content)
